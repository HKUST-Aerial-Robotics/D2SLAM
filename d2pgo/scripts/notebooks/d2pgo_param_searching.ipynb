# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.insert(0,'../')
from pose_graph_partitioning.pose_graph import *
from pose_graph_partitioning.pose_graph_partitioning import *
from simulate_utils import ATE, align_posegraphs, call_d2pgo_opti
from subprocess import PIPE, Popen
import copy

# %%
def call_d2pgo(input_data, output_data, agent_num, params, param_fixed={}, cmd="roslaunch d2pgo d2pgo_test_multi.launch "):
    command = f"{cmd} g2o_path:={input_data} output_path:={output_data} agent_num:={agent_num} "
    for k, v in params:
        command += f"{k}:={v[0]} "
    for k in param_fixed:
        v = param_fixed[k]
        command += f"{k}:={v} "
    p = Popen(command, shell=True, stdout=PIPE, stderr=PIPE)
    print(command)
    stdout, stderr = p.communicate()
    # return stdout, stderr
    # print(stdout.decode("utf-8"))
    return

def check_param_unique(params):
    cnt = 0
    for k, v in params:
        if len(v) > 1:
            return False, cnt
        cnt += 1
    return True, -1 

def print_res_to_table(res, sort_index="final_cost"):
    import tabulate
    output_table = []
    #Add title
    if len(res) == 0:
        return []
    sort_values = []
    for row in res:
        output_table.append([])
        for k in row:
            v = row[k]
            if isinstance(v, np.ndarray) or isinstance(v, list):
                output_table[-1].append(v[0])
            else:
                if k == "ATE_T":
                    output_table[-1].append(f"{v:.3f}m")
                elif k == "ATE_rot":
                    output_table[-1].append(f"{v*57.3:.3f}")
                elif k == "final_cost":
                    output_table[-1].append(f"{v:.3f}")
                else:
                    output_table[-1].append(v)
            if k == sort_index:
                sort_values.append(v)
    output_table = np.array(output_table)
    sort_values = np.array(sort_values)
    output_table = output_table[sort_values.argsort()]
    row0 = []
    for key in res[0]:
        row0.append(key)
    output_table = output_table.tolist()
    output_table.insert(0, row0)
    return tabulate.tabulate(output_table, tablefmt='html')

def grid_search(input_data, output_data, gt_data, agent_num, params, params_fixed={}, cmd="roslaunch d2pgo d2pgo_test_multi.launch ", is_root=True):
    #Gird search in param lists
    pg_gt = PoseGraph()
    pg_gt.read_g2o_single(gt_data)
    params_num = len(params)
    #DFS on params
    unique, row = check_param_unique(params)
    if unique:
        #Only one param, no need to grid search
        call_d2pgo(input_data, output_data, agent_num, params, params_fixed, cmd)
        pg_output = PoseGraph()
        pg_output.read_g2o_folder(output_data, prt=False)
        ate_T, ate_rot = ATE(pg_output, pg_gt)
        # align_posegraphs(pg_output, pg_gt)
        # ax = pg_gt.show("GT")
        # pg_output.show("output", ax=ax, clear=False)
        # print(params, ate_T, ate_rot)
        ret_data = {}
        for k, v in params:
            ret_data[k] = v[0]
        ret_data["ATE_T"] = ate_T
        ret_data["ATE_rot"] = ate_rot
        ret_data["final_cost"] = pg_output.evaluate_cost()
        # Add this data to output_data/result.txt
        with open(output_data + "/search_result.txt", "a") as f:
            # Save the params to a line of dict
            f.write(str(ret_data) + "\n")
        return [ret_data]
    else:
        #More than one param, need to grid search
        param_values = params[row][1]
        res = []
        for i in range(len(param_values)):
            new_params = copy.deepcopy(params)
            new_params[row][1] = [param_values[i]]
            ret = grid_search(input_data, output_data, gt_data, agent_num, new_params, params_fixed, cmd, is_root=False)
            for obj in ret:
                res.append(obj)
    return res

def random_search(input_data, output_data, gt_data, agent_num, params, max_trials=100, params_fixed={}, cmd="roslaunch d2pgo d2pgo_test_multi.launch ", is_root=True):
    #Gird search in param lists
    pg_gt = PoseGraph()
    pg_gt.read_g2o_single(gt_data)
    #DFS on params
    res = []
    for i in range(max_trials):
        # Take a random sample of params
        ret_data = {}
        params_instance = []
        for param in params:
            params_instance.append([param[0], [np.random.choice(param[1])]])
            ret_data[param[0]] = params_instance[-1][1]
        print(f"trial {i}:", params_instance)
        #Only one param, no need to grid search
        call_d2pgo(input_data, output_data, agent_num, params_instance, params_fixed, cmd)
        pg_output = PoseGraph()
        pg_output.read_g2o_folder(output_data, prt=False)
        ate_T, ate_rot = ATE(pg_output, pg_gt)
        # align_posegraphs(pg_output, pg_gt)
        # ax = pg_gt.show("GT")
        # pg_output.show("output", ax=ax, clear=False)
        # print(params, ate_T, ate_rot)
        ret_data["ATE_T"] = ate_T
        ret_data["ATE_rot"] = ate_rot
        ret_data["final_cost"] = pg_output.evaluate_cost()
        # Add this data to output_data/result.txt
        with open(output_data + "/search_result.txt", "a") as f:
            # Save the params to a line of dict
            f.write(str(ret_data) + "\n")
        res.append(ret_data)
    return res

# %%
intput_data = "/home/xuhao/data/pgo/parking-garage/input"
gt_data = "/home/xuhao/data/pgo/parking-garage/groundtruth.g2o"
output_data = "/home/xuhao/data/pgo/parking-garage/output/"
agent_num = 5
params = [
    ["max_steps", [10]],
    ["rho_frame_T", np.logspace(-4, 0, 10, base=10)],
    ["rho_frame_theta", np.logspace(-3, 0, 10, base=10)]
]
ret = grid_search(intput_data, output_data, gt_data, agent_num, params)
print_res_to_table(ret)

# %%
input_data = "/home/xuhao/data/d2slam/pgo/tum_corr_5/input"
gt_data = "/home/xuhao/data/d2slam/pgo/tum_corr_5/input/fullGraph_optimized.g2o"
output_data = "/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/"
agent_num = 5
# params = [
#     ["max_steps", [100]],
#     ["rho_frame_T", np.logspace(-5, -1, 10000, base=10)],
#     ["rho_frame_theta", np.logspace(-2, 2, 10000, base=10)],
#     ["eta_k", np.logspace(-1, 0, 100, base=10)],
#     ["enable_rot_init", ["false", "true"]]
# ]
params = [
    ["max_steps", [100]],
    ["rho_frame_T", np.linspace(0.01, 2.0, 10000)],
    ["rho_frame_theta", np.linspace(0.01, 2.0, 10000)],
    ["eta_k", np.linspace(0.5, 2, 100)],
    ["enable_rot_init", ["True"]]
]
# ret = grid_search(input_data, output_data, gt_data, agent_num, params)
ret = random_search(input_data, output_data, gt_data, agent_num, params, max_trials=1000)
print_res_to_table(ret)
# Out:
# trial 0: [['max_steps', [100]], ['rho_frame_T', [1.2168566856685668]], ['rho_frame_theta', [1.1294869486948695]], ['eta_k', [1.9090909090909092]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=1.2168566856685668 rho_frame_theta:=1.1294869486948695 eta_k:=1.9090909090909092 enable_rot_init:=True
# trial 1: [['max_steps', [100]], ['rho_frame_T', [0.4993899389938994]], ['rho_frame_theta', [1.983879387938794]], ['eta_k', [1.6515151515151516]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=0.4993899389938994 rho_frame_theta:=1.983879387938794 eta_k:=1.6515151515151516 enable_rot_init:=True
# trial 2: [['max_steps', [100]], ['rho_frame_T', [0.7601060106010601]], ['rho_frame_theta', [1.2276037603760377]], ['eta_k', [0.6060606060606061]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=0.7601060106010601 rho_frame_theta:=1.2276037603760377 eta_k:=0.6060606060606061 enable_rot_init:=True
# trial 3: [['max_steps', [100]], ['rho_frame_T', [1.2508890889088908]], ['rho_frame_theta', [0.6367136713671367]], ['eta_k', [0.8484848484848485]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=1.2508890889088908 rho_frame_theta:=0.6367136713671367 eta_k:=0.8484848484848485 enable_rot_init:=True
# trial 4: [['max_steps', [100]], ['rho_frame_T', [0.32086908690869087]], ['rho_frame_theta', [1.0815231523152316]], ['eta_k', [1.9242424242424243]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=0.32086908690869087 rho_frame_theta:=1.0815231523152316 eta_k:=1.9242424242424243 enable_rot_init:=True
# trial 5: [['max_steps', [100]], ['rho_frame_T', [1.6974897489748975]], ['rho_frame_theta', [1.9404930493049304]], ['eta_k', [1.2272727272727273]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=1.6974897489748975 rho_frame_theta:=1.9404930493049304 eta_k:=1.2272727272727273 enable_rot_init:=True
# trial 6: [['max_steps', [100]], ['rho_frame_T', [0.3103210321032103]], ['rho_frame_theta', [1.672015201520152]], ['eta_k', [0.9545454545454546]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=0.3103210321032103 rho_frame_theta:=1.672015201520152 eta_k:=0.9545454545454546 enable_rot_init:=True
# trial 7: [['max_steps', [100]], ['rho_frame_T', [1.5892229222922292]], ['rho_frame_theta', [1.2902950295029503]], ['eta_k', [1.4393939393939394]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=1.5892229222922292 rho_frame_theta:=1.2902950295029503 eta_k:=1.4393939393939394 enable_rot_init:=True
# trial 8: [['max_steps', [100]], ['rho_frame_T', [0.1554835483548355]], ['rho_frame_theta', [1.4668256825682569]], ['eta_k', [0.6212121212121212]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=0.1554835483548355 rho_frame_theta:=1.4668256825682569 eta_k:=0.6212121212121212 enable_rot_init:=True
# trial 9: [['max_steps', [100]], ['rho_frame_T', [0.3913221322132213]], ['rho_frame_theta', [1.5555885588558855]], ['eta_k', [1.4545454545454546]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=0.3913221322132213 rho_frame_theta:=1.5555885588558855 eta_k:=1.4545454545454546 enable_rot_init:=True
# trial 10: [['max_steps', [100]], ['rho_frame_T', [1.9032763276327633]], ['rho_frame_theta', [1.427021702170217]], ['eta_k', [1.6666666666666667]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=1.9032763276327633 rho_frame_theta:=1.427021702170217 eta_k:=1.6666666666666667 enable_rot_init:=True
# trial 11: [['max_steps', [100]], ['rho_frame_T', [1.485931593159316]], ['rho_frame_theta', [1.7195809580958095]], ['eta_k', [1.6212121212121213]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=1.485931593159316 rho_frame_theta:=1.7195809580958095 eta_k:=1.6212121212121213 enable_rot_init:=True
# trial 12: [['max_steps', [100]], ['rho_frame_T', [0.6948274827482748]], ['rho_frame_theta', [0.8415051505150515]], ['eta_k', [1.2575757575757576]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=0.6948274827482748 rho_frame_theta:=0.8415051505150515 eta_k:=1.2575757575757576 enable_rot_init:=True
# trial 13: [['max_steps', [100]], ['rho_frame_T', [0.49282228222822283]], ['rho_frame_theta', [1.9432793279327933]], ['eta_k', [0.8333333333333334]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=0.49282228222822283 rho_frame_theta:=1.9432793279327933 eta_k:=0.8333333333333334 enable_rot_init:=True
# trial 14: [['max_steps', [100]], ['rho_frame_T', [0.7825952595259525]], ['rho_frame_theta', [1.9178047804780478]], ['eta_k', [1.803030303030303]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=0.7825952595259525 rho_frame_theta:=1.9178047804780478 eta_k:=1.803030303030303 enable_rot_init:=True
# trial 15: [['max_steps', [100]], ['rho_frame_T', [1.2411371137113711]], ['rho_frame_theta', [0.8562326232623262]], ['eta_k', [0.5757575757575758]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=1.2411371137113711 rho_frame_theta:=0.8562326232623262 eta_k:=0.5757575757575758 enable_rot_init:=True
# trial 16: [['max_steps', [100]], ['rho_frame_T', [1.50006200620062]], ['rho_frame_theta', [1.6214641464146415]], ['eta_k', [0.9090909090909092]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=1.50006200620062 rho_frame_theta:=1.6214641464146415 eta_k:=0.9090909090909092 enable_rot_init:=True
# trial 17: [['max_steps', [100]], ['rho_frame_T', [1.9966166616661667]], ['rho_frame_theta', [0.46555655565556553]], ['eta_k', [0.5]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=1.9966166616661667 rho_frame_theta:=0.46555655565556553 eta_k:=0.5 enable_rot_init:=True
# trial 18: [['max_steps', [100]], ['rho_frame_T', [1.4156775677567757]], ['rho_frame_theta', [1.706843684368437]], ['eta_k', [0.7272727272727273]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=1.4156775677567757 rho_frame_theta:=1.706843684368437 eta_k:=0.7272727272727273 enable_rot_init:=True
# trial 19: [['max_steps', [100]], ['rho_frame_T', [1.3066146614661467]], ['rho_frame_theta', [1.5975817581758176]], ['eta_k', [1.5151515151515151]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=1.3066146614661467 rho_frame_theta:=1.5975817581758176 eta_k:=1.5151515151515151 enable_rot_init:=True
# trial 20: [['max_steps', [100]], ['rho_frame_T', [1.3502000200020001]], ['rho_frame_theta', [1.0912751275127512]], ['eta_k', [0.7575757575757576]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=1.3502000200020001 rho_frame_theta:=1.0912751275127512 eta_k:=0.7575757575757576 enable_rot_init:=True
# trial 21: [['max_steps', [100]], ['rho_frame_T', [1.2377537753775378]], ['rho_frame_theta', [1.3643304330433044]], ['eta_k', [0.8787878787878788]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=1.2377537753775378 rho_frame_theta:=1.3643304330433044 eta_k:=0.8787878787878788 enable_rot_init:=True
# trial 22: [['max_steps', [100]], ['rho_frame_T', [0.454013401340134]], ['rho_frame_theta', [0.010597059705970597]], ['eta_k', [0.9090909090909092]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=0.454013401340134 rho_frame_theta:=0.010597059705970597 eta_k:=0.9090909090909092 enable_rot_init:=True
# trial 23: [['max_steps', [100]], ['rho_frame_T', [1.1876007600760077]], ['rho_frame_theta', [1.9677587758775876]], ['eta_k', [1.3636363636363638]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=1.1876007600760077 rho_frame_theta:=1.9677587758775876 eta_k:=1.3636363636363638 enable_rot_init:=True
# trial 24: [['max_steps', [100]], ['rho_frame_T', [1.7816751675167517]], ['rho_frame_theta', [0.7969246924692469]], ['eta_k', [1.7121212121212122]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=1.7816751675167517 rho_frame_theta:=0.7969246924692469 eta_k:=1.7121212121212122 enable_rot_init:=True
# trial 25: [['max_steps', [100]], ['rho_frame_T', [0.08264226422642264]], ['rho_frame_theta', [1.6023582358235824]], ['eta_k', [1.9545454545454546]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=0.08264226422642264 rho_frame_theta:=1.6023582358235824 eta_k:=1.9545454545454546 enable_rot_init:=True
# trial 26: [['max_steps', [100]], ['rho_frame_T', [0.13379037903790378]], ['rho_frame_theta', [0.903997399739974]], ['eta_k', [1.7424242424242424]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=0.13379037903790378 rho_frame_theta:=0.903997399739974 eta_k:=1.7424242424242424 enable_rot_init:=True
# trial 27: [['max_steps', [100]], ['rho_frame_T', [0.1501100110011001]], ['rho_frame_theta', [1.152971297129713]], ['eta_k', [0.8787878787878788]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=0.1501100110011001 rho_frame_theta:=1.152971297129713 eta_k:=0.8787878787878788 enable_rot_init:=True
# trial 28: [['max_steps', [100]], ['rho_frame_T', [1.0687858785878588]], ['rho_frame_theta', [1.1338653865386539]], ['eta_k', [1.4242424242424243]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=1.0687858785878588 rho_frame_theta:=1.1338653865386539 eta_k:=1.4242424242424243 enable_rot_init:=True
# trial 29: [['max_steps', [100]], ['rho_frame_T', [1.885961596159616]], ['rho_frame_theta', [0.837922792279228]], ['eta_k', [1.3333333333333335]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=1.885961596159616 rho_frame_theta:=0.837922792279228 eta_k:=1.3333333333333335 enable_rot_init:=True
# trial 30: [['max_steps', [100]], ['rho_frame_T', [1.225016501650165]], ['rho_frame_theta', [1.006094609460946]], ['eta_k', [1.4545454545454546]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=1.225016501650165 rho_frame_theta:=1.006094609460946 eta_k:=1.4545454545454546 enable_rot_init:=True
# trial 31: [['max_steps', [100]], ['rho_frame_T', [1.8025722572257226]], ['rho_frame_theta', [0.10194719471947195]], ['eta_k', [1.9090909090909092]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=1.8025722572257226 rho_frame_theta:=0.10194719471947195 eta_k:=1.9090909090909092 enable_rot_init:=True
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb 单元格 4 in <cell line: 20>()
#      <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#W3sZmlsZQ%3D%3D?line=11'>12</a> params = [
#      <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#W3sZmlsZQ%3D%3D?line=12'>13</a>     ["max_steps", [100]],
#      <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#W3sZmlsZQ%3D%3D?line=13'>14</a>     ["rho_frame_T", np.linspace(0.01, 2.0, 10000)],
#    (...)
#      <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#W3sZmlsZQ%3D%3D?line=16'>17</a>     ["enable_rot_init", ["True"]]
#      <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#W3sZmlsZQ%3D%3D?line=17'>18</a> ]
#      <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#W3sZmlsZQ%3D%3D?line=18'>19</a> # ret = grid_search(input_data, output_data, gt_data, agent_num, params)
# ---> <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#W3sZmlsZQ%3D%3D?line=19'>20</a> ret = random_search(input_data, output_data, gt_data, agent_num, params, max_trials=1000)
#      <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#W3sZmlsZQ%3D%3D?line=20'>21</a> print_res_to_table(ret)
#
# /home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb 单元格 4 in random_search(input_data, output_data, gt_data, agent_num, params, max_trials, params_fixed, cmd, is_root)
#     <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#W3sZmlsZQ%3D%3D?line=109'>110</a> print(f"trial {i}:", params_instance)
#     <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#W3sZmlsZQ%3D%3D?line=110'>111</a> #Only one param, no need to grid search
# --> <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#W3sZmlsZQ%3D%3D?line=111'>112</a> call_d2pgo(input_data, output_data, agent_num, params_instance, params_fixed, cmd)
#     <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#W3sZmlsZQ%3D%3D?line=112'>113</a> pg_output = PoseGraph()
#     <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#W3sZmlsZQ%3D%3D?line=113'>114</a> pg_output.read_g2o_folder(output_data, prt=False)
#
# /home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb 单元格 4 in call_d2pgo(input_data, output_data, agent_num, params, param_fixed, cmd)
#       <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#W3sZmlsZQ%3D%3D?line=7'>8</a> p = Popen(command, shell=True, stdout=PIPE, stderr=PIPE)
#       <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#W3sZmlsZQ%3D%3D?line=8'>9</a> print(command)
# ---> <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#W3sZmlsZQ%3D%3D?line=9'>10</a> stdout, stderr = p.communicate()
#      <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#W3sZmlsZQ%3D%3D?line=10'>11</a> # return stdout, stderr
#      <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#W3sZmlsZQ%3D%3D?line=11'>12</a> # print(stdout.decode("utf-8"))
#      <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#W3sZmlsZQ%3D%3D?line=12'>13</a> return
#
# File ~/anaconda3/lib/python3.8/subprocess.py:1024, in Popen.communicate(self, input, timeout)
#    1021     endtime = None
#    1023 try:
# -> 1024     stdout, stderr = self._communicate(input, endtime, timeout)
#    1025 except KeyboardInterrupt:
#    1026     # https://bugs.python.org/issue25942
#    1027     # See the detailed comment in .wait().
#    1028     if timeout is not None:
#
# File ~/anaconda3/lib/python3.8/subprocess.py:1866, in Popen._communicate(self, input, endtime, orig_timeout)
#    1859     self._check_timeout(endtime, orig_timeout,
#    1860                         stdout, stderr,
#    1861                         skip_check_and_raise=True)
#    1862     raise RuntimeError(  # Impossible :)
#    1863         '_check_timeout(..., skip_check_and_raise=True) '
#    1864         'failed to raise TimeoutExpired.')
# -> 1866 ready = selector.select(timeout)
#    1867 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    1869 # XXX Rewrite these to use non-blocking I/O on the file
#    1870 # objects; they are no longer using C stdio!
#
# File ~/anaconda3/lib/python3.8/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     413 ready = []
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#     417     return ready
#
# KeyboardInterrupt:

# %%
#Show the convergence of the results
intput_data = "/home/xuhao/data/d2slam/pgo/torus3D/input/"
gt_data = "/home/xuhao/data/d2slam/pgo/torus3D/groundtruth.g2o"
output_data = "/home/xuhao/data/d2slam/pgo/torus3D/output/"
agent_num = 5
params = [
    ["max_steps", np.logspace(0, 2, 10, base=10, dtype=int)],
    ["debug_rot_init_only", ["true"]]
]
fixed_param = {
    "debug_rot_init_only":"true"
}
ret = grid_search(intput_data, output_data, gt_data, agent_num, params, fixed_param)
print_res_to_table(ret, "max_steps")
# Out:
# '<table>\n<tbody>\n<tr><td>max_steps</td><td>debug_rot_init_only</td><td>ATE_T  </td><td>ATE_rot</td></tr>\n<tr><td>1        </td><td>true               </td><td>16.115m</td><td>76.939 </td></tr>\n<tr><td>1        </td><td>true               </td><td>11.555m</td><td>118.155</td></tr>\n<tr><td>2        </td><td>true               </td><td>16.115m</td><td>45.946 </td></tr>\n<tr><td>4        </td><td>true               </td><td>16.115m</td><td>4.853  </td></tr>\n<tr><td>7        </td><td>true               </td><td>16.115m</td><td>4.732  </td></tr>\n<tr><td>12       </td><td>true               </td><td>16.114m</td><td>4.639  </td></tr>\n<tr><td>21       </td><td>true               </td><td>16.114m</td><td>4.289  </td></tr>\n<tr><td>35       </td><td>true               </td><td>16.112m</td><td>3.784  </td></tr>\n<tr><td>59       </td><td>true               </td><td>16.110m</td><td>3.402  </td></tr>\n<tr><td>100      </td><td>true               </td><td>16.106m</td><td>3.200  </td></tr>\n</tbody>\n</table>'

# %%
intput_data = "/home/xuhao/data/d2slam/pgo/torus3D/input/"
gt_data = "/home/xuhao/data/d2slam/pgo/torus3D/groundtruth.g2o"
output_data = "/home/xuhao/data/d2slam/pgo/torus3D/output/"
agent_num = 5
params = [
    ["rho_rot_mat", np.logspace(-3, 1, 10, base=10)]
]
fixed_param = {
    "debug_rot_init_only":"true",
    "max_steps": 20
}
ret = grid_search(intput_data, output_data, gt_data, agent_num, params, fixed_param)
print_res_to_table(ret, "ATE_rot")

# %%
#Search for initial rotation
input_data = "/home/xuhao/data/d2slam/pgo/tum_corr/input"
gt_data = "/home/xuhao/data/d2slam/pgo/tum_corr/groundtruth.g2o"
output_data = "/home/xuhao/data/d2slam/pgo/tum_corr/output/"
agent_num = 2
params = [
    ["rho_rot_mat", np.logspace(-3, 1, 10, base=10)],
    ["max_steps", np.logspace(-3, 1, 10, base=10)]
]
fixed_param = {
    "debug_rot_init_only":"true",
    "max_steps": 100
}
ret = grid_search(input_data, output_data, gt_data, agent_num, params, fixed_param)
print_res_to_table(ret)

# %%
#Show the convergence of the results
input_data = "/home/xuhao/data/d2slam/pgo/tum_corr/input"
gt_data = "/home/xuhao/data/d2slam/pgo/tum_corr/groundtruth.g2o"
output_data = "/home/xuhao/data/d2slam/pgo/tum_corr/output/"
agent_num = 2
params = [
    ["max_steps", np.logspace(0, 2, 10, base=10, dtype=int)],
]
fixed_param = {
    "debug_rot_init_only":"true",
    "eta_k": 0.4
}
ret = grid_search(input_data, output_data, gt_data, agent_num, params, fixed_param)
print_res_to_table(ret, "max_steps")
# Out:
# '<table>\n<tbody>\n<tr><td>max_steps</td><td>ATE_T </td><td>ATE_rot</td></tr>\n<tr><td>1        </td><td>2.788m</td><td>50.804 </td></tr>\n<tr><td>1        </td><td>2.788m</td><td>50.804 </td></tr>\n<tr><td>2        </td><td>2.927m</td><td>5.532  </td></tr>\n<tr><td>4        </td><td>2.915m</td><td>4.628  </td></tr>\n<tr><td>7        </td><td>2.911m</td><td>4.261  </td></tr>\n<tr><td>12       </td><td>2.903m</td><td>4.040  </td></tr>\n<tr><td>21       </td><td>2.890m</td><td>3.913  </td></tr>\n<tr><td>35       </td><td>2.879m</td><td>3.890  </td></tr>\n<tr><td>59       </td><td>2.870m</td><td>4.007  </td></tr>\n<tr><td>100      </td><td>2.869m</td><td>4.278  </td></tr>\n</tbody>\n</table>'

# %%
def search_function(param):
    pg_output = call_d2pgo_opti(input_data, output_data, agent_num = agent_num, max_steps=50, enable_rot_init=True, 
        eta_k=param['eta_k'], rho_frame_theta=param['rho_frame_theta'], rho_frame_T=param['rho_frame_T'])
    return pg_output.evaluate_cost()
input_data = "/home/xuhao/data/d2slam/pgo/tum_corr_5/input"
gt_data = "/home/xuhao/data/d2slam/pgo/tum_corr_5/input/fullGraph_optimized.g2o"
output_data = "/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/"
agent_num = 5
from hyperopt import hp, fmin, tpe
# params = [
#     ["max_steps", [100]],
#     ["rho_frame_T", np.linspace(0.01, 2.0, 10000)],
#     ["rho_frame_theta", np.linspace(0.01, 2.0, 10000)],
#     ["eta_k", np.linspace(0.5, 2, 100)],
#     ["enable_rot_init", ["True"]]
# ]
space = {
    "rho_frame_T": hp.uniform("rho_frame_T", 0.0, 10.0),
    "rho_frame_theta": hp.uniform("rho_frame_theta", 0.0, 10.0),
    "eta_k": hp.uniform("eta_k", 0, 5.0),
}

best = fmin(search_function, space, algo=tpe.suggest, max_evals=100)
# Out:
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# Total agents 5 keyframes 12065 edges 16814 inter edge 3165 comm_vol 4754 keyframes 759<->3030
# 100%|██████████| 100/100 [27:57<00:00, 16.77s/trial, best loss: 72.6701311817301]

# %%
print(best)
# Out:
# {'eta_k': 1.8775252446543182, 'rho_frame_T': 1.6746805631401465, 'rho_frame_theta': 3.3446172271357684}
