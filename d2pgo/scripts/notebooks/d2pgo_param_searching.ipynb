# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.insert(0,'../')
from pose_graph_partitioning.pose_graph import *
from pose_graph_partitioning.pose_graph_partitioning import *
from simulate_utils import ATE, align_posegraphs, call_d2pgo_opti
from subprocess import PIPE, Popen
import copy

# %%
def call_d2pgo(input_data, output_data, agent_num, params, param_fixed={}, cmd="roslaunch d2pgo d2pgo_test_multi.launch "):
    command = f"{cmd} g2o_path:={input_data} output_path:={output_data} agent_num:={agent_num} "
    for k, v in params:
        command += f"{k}:={v[0]} "
    for k in param_fixed:
        v = param_fixed[k]
        command += f"{k}:={v} "
    p = Popen(command, shell=True, stdout=PIPE, stderr=PIPE)
    print(command)
    stdout, stderr = p.communicate()
    # return stdout, stderr
    # print(stdout.decode("utf-8"))
    return

def check_param_unique(params):
    cnt = 0
    for k, v in params:
        if len(v) > 1:
            return False, cnt
        cnt += 1
    return True, -1 

def print_res_to_table(res, sort_index="final_cost"):
    import tabulate
    output_table = []
    #Add title
    if len(res) == 0:
        return []
    sort_values = []
    for row in res:
        output_table.append([])
        for k in row:
            v = row[k]
            if isinstance(v, np.ndarray) or isinstance(v, list):
                output_table[-1].append(v[0])
            else:
                if k == "ATE_T":
                    output_table[-1].append(f"{v:.3f}m")
                elif k == "ATE_rot":
                    output_table[-1].append(f"{v*57.3:.3f}")
                elif k == "final_cost":
                    output_table[-1].append(f"{v:.3f}")
                else:
                    output_table[-1].append(v)
            if k == sort_index:
                sort_values.append(v)
    output_table = np.array(output_table)
    sort_values = np.array(sort_values)
    output_table = output_table[sort_values.argsort()]
    row0 = []
    for key in res[0]:
        row0.append(key)
    output_table = output_table.tolist()
    output_table.insert(0, row0)
    return tabulate.tabulate(output_table, tablefmt='html')

def grid_search(input_data, output_data, gt_data, agent_num, params, params_fixed={}, cmd="roslaunch d2pgo d2pgo_test_multi.launch ", is_root=True):
    #Gird search in param lists
    pg_gt = PoseGraph()
    pg_gt.read_g2o_single(gt_data)
    params_num = len(params)
    #DFS on params
    unique, row = check_param_unique(params)
    if unique:
        #Only one param, no need to grid search
        call_d2pgo(input_data, output_data, agent_num, params, params_fixed, cmd)
        pg_output = PoseGraph()
        pg_output.read_g2o_folder(output_data, prt=False)
        ate_T, ate_rot = ATE(pg_output, pg_gt)
        # align_posegraphs(pg_output, pg_gt)
        # ax = pg_gt.show("GT")
        # pg_output.show("output", ax=ax, clear=False)
        # print(params, ate_T, ate_rot)
        ret_data = {}
        for k, v in params:
            ret_data[k] = v[0]
        ret_data["ATE_T"] = ate_T
        ret_data["ATE_rot"] = ate_rot
        ret_data["final_cost"] = pg_output.evaluate_cost()
        # Add this data to output_data/result.txt
        with open(output_data + "/search_result.txt", "a") as f:
            # Save the params to a line of dict
            f.write(str(ret_data) + "\n")
        return [ret_data]
    else:
        #More than one param, need to grid search
        param_values = params[row][1]
        res = []
        for i in range(len(param_values)):
            new_params = copy.deepcopy(params)
            new_params[row][1] = [param_values[i]]
            ret = grid_search(input_data, output_data, gt_data, agent_num, new_params, params_fixed, cmd, is_root=False)
            for obj in ret:
                res.append(obj)
    return res

def random_search(input_data, output_data, agent_num, params, gt_data=None, max_trials=100, params_fixed={}, cmd="roslaunch d2pgo d2pgo_test_multi.launch ", is_root=True):
    #Gird search in param lists
    if gt_data is not None:
        pg_gt = PoseGraph()
        pg_gt.read_g2o_single(gt_data)
    #DFS on params
    res = []
    for i in range(max_trials):
        # Take a random sample of params
        ret_data = {}
        params_instance = []
        for param in params:
            params_instance.append([param[0], [np.random.choice(param[1])]])
            ret_data[param[0]] = params_instance[-1][1]
        print(f"trial {i}:", params_instance)
        #Only one param, no need to grid search
        call_d2pgo(input_data, output_data, agent_num, params_instance, params_fixed, cmd)
        pg_output = PoseGraph()
        pg_output.read_g2o_folder(output_data, prt=False)
        if gt_data is not None:
            ate_T, ate_rot = ATE(pg_output, pg_gt)
            ret_data["ATE_T"] = ate_T
            ret_data["ATE_rot"] = ate_rot
        ret_data["final_cost"] = pg_output.evaluate_cost()
        # Add this data to output_data/result.txt
        with open(output_data + "/search_result.txt", "a") as f:
            # Save the params to a line of dict
            f.write(str(ret_data) + "\n")
        res.append(ret_data)
    return res

# %%
input_data = "/home/xuhao/data/d2slam/pgo/parking-garage/input"
gt_data = "/home/xuhao/data/d2slam/pgo/parking-garage/groundtruth.g2o"
output_data = "/home/xuhao/data/d2slam/pgo/parking-garage/searching-output/"
agent_num = 5
params = [
    ["max_steps", [100]],
    ["rho_frame_T", np.linspace(0.01, 2.0, 10000)],
    ["rho_frame_theta", np.linspace(0.01, 2.0, 10000)],
    ["eta_k", np.linspace(0.5, 3, 100)],
    ["enable_rot_init", ["True", "False"]]
]
ret = random_search(input_data, output_data, agent_num, params, max_trials=1000)
print_res_to_table(ret)
# Out:
# trial 0: [['max_steps', [100]], ['rho_frame_T', [0.12483448344834483]], ['rho_frame_theta', [0.23767876787678768]], ['eta_k', [1.196969696969697]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/parking-garage/input output_path:=/home/xuhao/data/d2slam/pgo/parking-garage/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=0.12483448344834483 rho_frame_theta:=0.23767876787678768 eta_k:=1.196969696969697 enable_rot_init:=True
# trial 1: [['max_steps', [100]], ['rho_frame_T', [1.9882578257825783]], ['rho_frame_theta', [0.4092339233923392]], ['eta_k', [1.7424242424242424]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/parking-garage/input output_path:=/home/xuhao/data/d2slam/pgo/parking-garage/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=1.9882578257825783 rho_frame_theta:=0.4092339233923392 eta_k:=1.7424242424242424 enable_rot_init:=True
# trial 2: [['max_steps', [100]], ['rho_frame_T', [0.09100110011001099]], ['rho_frame_theta', [0.6454705470547054]], ['eta_k', [0.6515151515151515]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/parking-garage/input output_path:=/home/xuhao/data/d2slam/pgo/parking-garage/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=0.09100110011001099 rho_frame_theta:=0.6454705470547054 eta_k:=0.6515151515151515 enable_rot_init:=True
# trial 3: [['max_steps', [100]], ['rho_frame_T', [0.0908020802080208]], ['rho_frame_theta', [0.22752875287528754]], ['eta_k', [1.6363636363636365]], ['enable_rot_init', ['False']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/parking-garage/input output_path:=/home/xuhao/data/d2slam/pgo/parking-garage/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=0.0908020802080208 rho_frame_theta:=0.22752875287528754 eta_k:=1.6363636363636365 enable_rot_init:=False
# trial 4: [['max_steps', [100]], ['rho_frame_T', [1.4582678267826783]], ['rho_frame_theta', [0.1722012201220122]], ['eta_k', [0.6363636363636364]], ['enable_rot_init', ['False']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/parking-garage/input output_path:=/home/xuhao/data/d2slam/pgo/parking-garage/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=1.4582678267826783 rho_frame_theta:=0.1722012201220122 eta_k:=0.6363636363636364 enable_rot_init:=False
# trial 5: [['max_steps', [100]], ['rho_frame_T', [0.2715121512151215]], ['rho_frame_theta', [1.0003230323032302]], ['eta_k', [1.0454545454545454]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/parking-garage/input output_path:=/home/xuhao/data/d2slam/pgo/parking-garage/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=0.2715121512151215 rho_frame_theta:=1.0003230323032302 eta_k:=1.0454545454545454 enable_rot_init:=True
# trial 6: [['max_steps', [100]], ['rho_frame_T', [1.532900290029003]], ['rho_frame_theta', [0.40386038603860386]], ['eta_k', [0.6212121212121212]], ['enable_rot_init', ['False']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/parking-garage/input output_path:=/home/xuhao/data/d2slam/pgo/parking-garage/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=1.532900290029003 rho_frame_theta:=0.40386038603860386 eta_k:=0.6212121212121212 enable_rot_init:=False
# trial 7: [['max_steps', [100]], ['rho_frame_T', [1.2656165616561657]], ['rho_frame_theta', [1.7187848784878488]], ['eta_k', [1.7878787878787878]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/parking-garage/input output_path:=/home/xuhao/data/d2slam/pgo/parking-garage/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=1.2656165616561657 rho_frame_theta:=1.7187848784878488 eta_k:=1.7878787878787878 enable_rot_init:=True
# trial 8: [['max_steps', [100]], ['rho_frame_T', [1.9882578257825783]], ['rho_frame_theta', [1.2751695169516952]], ['eta_k', [1.4242424242424243]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/parking-garage/input output_path:=/home/xuhao/data/d2slam/pgo/parking-garage/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=1.9882578257825783 rho_frame_theta:=1.2751695169516952 eta_k:=1.4242424242424243 enable_rot_init:=True
# trial 9: [['max_steps', [100]], ['rho_frame_T', [0.29201120112011203]], ['rho_frame_theta', [1.6638553855385538]], ['eta_k', [1.4242424242424243]], ['enable_rot_init', ['False']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/parking-garage/input output_path:=/home/xuhao/data/d2slam/pgo/parking-garage/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=0.29201120112011203 rho_frame_theta:=1.6638553855385538 eta_k:=1.4242424242424243 enable_rot_init:=False
# trial 10: [['max_steps', [100]], ['rho_frame_T', [0.48724972497249724]], ['rho_frame_theta', [1.521954195419542]], ['eta_k', [0.9242424242424243]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/parking-garage/input output_path:=/home/xuhao/data/d2slam/pgo/parking-garage/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=0.48724972497249724 rho_frame_theta:=1.521954195419542 eta_k:=0.9242424242424243 enable_rot_init:=True
# trial 11: [['max_steps', [100]], ['rho_frame_T', [1.35000100010001]], ['rho_frame_theta', [1.3084058405840584]], ['eta_k', [1.121212121212121]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/parking-garage/input output_path:=/home/xuhao/data/d2slam/pgo/parking-garage/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=1.35000100010001 rho_frame_theta:=1.3084058405840584 eta_k:=1.121212121212121 enable_rot_init:=True
# trial 12: [['max_steps', [100]], ['rho_frame_T', [0.6534313431343134]], ['rho_frame_theta', [0.22673267326732674]], ['eta_k', [1.2121212121212122]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/parking-garage/input output_path:=/home/xuhao/data/d2slam/pgo/parking-garage/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=0.6534313431343134 rho_frame_theta:=0.22673267326732674 eta_k:=1.2121212121212122 enable_rot_init:=True
# trial 13: [['max_steps', [100]], ['rho_frame_T', [2.0]], ['rho_frame_theta', [0.18274927492749277]], ['eta_k', [0.9848484848484849]], ['enable_rot_init', ['False']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/parking-garage/input output_path:=/home/xuhao/data/d2slam/pgo/parking-garage/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=2.0 rho_frame_theta:=0.18274927492749277 eta_k:=0.9848484848484849 enable_rot_init:=False
# trial 14: [['max_steps', [100]], ['rho_frame_T', [1.586038603860386]], ['rho_frame_theta', [1.3937853785378538]], ['eta_k', [1.0]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/parking-garage/input output_path:=/home/xuhao/data/d2slam/pgo/parking-garage/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=1.586038603860386 rho_frame_theta:=1.3937853785378538 eta_k:=1.0 enable_rot_init:=True
# trial 15: [['max_steps', [100]], ['rho_frame_T', [0.4862546254625463]], ['rho_frame_theta', [1.8996939693969397]], ['eta_k', [0.9393939393939394]], ['enable_rot_init', ['False']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/parking-garage/input output_path:=/home/xuhao/data/d2slam/pgo/parking-garage/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=0.4862546254625463 rho_frame_theta:=1.8996939693969397 eta_k:=0.9393939393939394 enable_rot_init:=False
# trial 16: [['max_steps', [100]], ['rho_frame_T', [1.5247404740474046]], ['rho_frame_theta', [1.7249544954495448]], ['eta_k', [1.7575757575757576]], ['enable_rot_init', ['False']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/parking-garage/input output_path:=/home/xuhao/data/d2slam/pgo/parking-garage/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=1.5247404740474046 rho_frame_theta:=1.7249544954495448 eta_k:=1.7575757575757576 enable_rot_init:=False
# trial 17: [['max_steps', [100]], ['rho_frame_T', [1.1356565656565656]], ['rho_frame_theta', [0.08423442344234423]], ['eta_k', [0.9393939393939394]], ['enable_rot_init', ['False']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/parking-garage/input output_path:=/home/xuhao/data/d2slam/pgo/parking-garage/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=1.1356565656565656 rho_frame_theta:=0.08423442344234423 eta_k:=0.9393939393939394 enable_rot_init:=False
# trial 18: [['max_steps', [100]], ['rho_frame_T', [1.095056505650565]], ['rho_frame_theta', [0.20344734473447346]], ['eta_k', [1.3333333333333335]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/parking-garage/input output_path:=/home/xuhao/data/d2slam/pgo/parking-garage/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=1.095056505650565 rho_frame_theta:=0.20344734473447346 eta_k:=1.3333333333333335 enable_rot_init:=True
# trial 19: [['max_steps', [100]], ['rho_frame_T', [1.072169216921692]], ['rho_frame_theta', [0.6098459845984598]], ['eta_k', [1.893939393939394]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/parking-garage/input output_path:=/home/xuhao/data/d2slam/pgo/parking-garage/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=1.072169216921692 rho_frame_theta:=0.6098459845984598 eta_k:=1.893939393939394 enable_rot_init:=True
# trial 20: [['max_steps', [100]], ['rho_frame_T', [1.009079907990799]], ['rho_frame_theta', [1.7806800680068007]], ['eta_k', [1.1515151515151514]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/parking-garage/input output_path:=/home/xuhao/data/d2slam/pgo/parking-garage/searching-output/ agent_num:=5 max_steps:=100 rho_frame_T:=1.009079907990799 rho_frame_theta:=1.7806800680068007 eta_k:=1.1515151515151514 enable_rot_init:=True
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb 单元格 3 in <cell line: 12>()
#       <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#W2sZmlsZQ%3D%3D?line=3'>4</a> agent_num = 5
#       <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#W2sZmlsZQ%3D%3D?line=4'>5</a> params = [
#       <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#W2sZmlsZQ%3D%3D?line=5'>6</a>     ["max_steps", [100]],
#       <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#W2sZmlsZQ%3D%3D?line=6'>7</a>     ["rho_frame_T", np.linspace(0.01, 2.0, 10000)],
#    (...)
#      <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#W2sZmlsZQ%3D%3D?line=9'>10</a>     ["enable_rot_init", ["True", "False"]]
#      <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#W2sZmlsZQ%3D%3D?line=10'>11</a> ]
# ---> <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#W2sZmlsZQ%3D%3D?line=11'>12</a> ret = random_search(input_data, output_data, agent_num, params, max_trials=1000)
#      <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#W2sZmlsZQ%3D%3D?line=12'>13</a> print_res_to_table(ret)
#
# /home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb 单元格 3 in random_search(input_data, output_data, agent_num, params, gt_data, max_trials, params_fixed, cmd, is_root)
#     <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#W2sZmlsZQ%3D%3D?line=110'>111</a> print(f"trial {i}:", params_instance)
#     <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#W2sZmlsZQ%3D%3D?line=111'>112</a> #Only one param, no need to grid search
# --> <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#W2sZmlsZQ%3D%3D?line=112'>113</a> call_d2pgo(input_data, output_data, agent_num, params_instance, params_fixed, cmd)
#     <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#W2sZmlsZQ%3D%3D?line=113'>114</a> pg_output = PoseGraph()
#     <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#W2sZmlsZQ%3D%3D?line=114'>115</a> pg_output.read_g2o_folder(output_data, prt=False)
#
# /home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb 单元格 3 in call_d2pgo(input_data, output_data, agent_num, params, param_fixed, cmd)
#       <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#W2sZmlsZQ%3D%3D?line=7'>8</a> p = Popen(command, shell=True, stdout=PIPE, stderr=PIPE)
#       <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#W2sZmlsZQ%3D%3D?line=8'>9</a> print(command)
# ---> <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#W2sZmlsZQ%3D%3D?line=9'>10</a> stdout, stderr = p.communicate()
#      <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#W2sZmlsZQ%3D%3D?line=10'>11</a> # return stdout, stderr
#      <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#W2sZmlsZQ%3D%3D?line=11'>12</a> # print(stdout.decode("utf-8"))
#      <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#W2sZmlsZQ%3D%3D?line=12'>13</a> return
#
# File ~/anaconda3/lib/python3.8/subprocess.py:1024, in Popen.communicate(self, input, timeout)
#    1021     endtime = None
#    1023 try:
# -> 1024     stdout, stderr = self._communicate(input, endtime, timeout)
#    1025 except KeyboardInterrupt:
#    1026     # https://bugs.python.org/issue25942
#    1027     # See the detailed comment in .wait().
#    1028     if timeout is not None:
#
# File ~/anaconda3/lib/python3.8/subprocess.py:1866, in Popen._communicate(self, input, endtime, orig_timeout)
#    1859     self._check_timeout(endtime, orig_timeout,
#    1860                         stdout, stderr,
#    1861                         skip_check_and_raise=True)
#    1862     raise RuntimeError(  # Impossible :)
#    1863         '_check_timeout(..., skip_check_and_raise=True) '
#    1864         'failed to raise TimeoutExpired.')
# -> 1866 ready = selector.select(timeout)
#    1867 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    1869 # XXX Rewrite these to use non-blocking I/O on the file
#    1870 # objects; they are no longer using C stdio!
#
# File ~/anaconda3/lib/python3.8/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     413 ready = []
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#     417     return ready
#
# KeyboardInterrupt:

# %%
input_data = "/home/xuhao/data/d2slam/pgo/tum_corr_5/input/"
gt_data = "/home/xuhao/data/d2slam/pgo/tum_corr_5/input/fullGraph_optimized.g2o"
output_data = "/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/"
agent_num = 5
# params = [
#     ["max_steps", [100]],
#     ["rho_frame_T", np.logspace(-5, -1, 10000, base=10)],
#     ["rho_frame_theta", np.logspace(-2, 2, 10000, base=10)],
#     ["eta_k", np.logspace(-1, 0, 100, base=10)],
#     ["enable_rot_init", ["false", "true"]]
# ]
params = [
    ["max_steps", [10000]],
    ["rho_frame_T", np.linspace(0.01, 5.0, 10000)],
    ["rho_frame_theta", np.linspace(0.01, 5.0, 10000)],
    ["eta_k", np.linspace(0.5, 3, 100)],
    ["rho_rot_mat", np.linspace(0.001, 3, 100)],
    ["enable_rot_init", ["True"]]
]
ret = random_search(input_data, output_data, agent_num, params, max_trials=1000)
print_res_to_table(ret)
# Out:
# trial 0: [['max_steps', [10000]], ['rho_frame_T', [2.84011201120112]], ['rho_frame_theta', [0.21161616161616165]], ['eta_k', [1.8383838383838385]], ['rho_rot_mat', [0.9703737373737374]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=2.84011201120112 rho_frame_theta:=0.21161616161616165 eta_k:=1.8383838383838385 rho_rot_mat:=0.9703737373737374 enable_rot_init:=True
# trial 1: [['max_steps', [10000]], ['rho_frame_T', [1.1802720272027203]], ['rho_frame_theta', [2.1773737373737374]], ['eta_k', [2.974747474747475]], ['rho_rot_mat', [1.9094545454545455]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=1.1802720272027203 rho_frame_theta:=2.1773737373737374 eta_k:=2.974747474747475 rho_rot_mat:=1.9094545454545455 enable_rot_init:=True
# trial 2: [['max_steps', [10000]], ['rho_frame_T', [3.433981398139814]], ['rho_frame_theta', [0.9377337733773379]], ['eta_k', [2.898989898989899]], ['rho_rot_mat', [1.6671111111111112]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=3.433981398139814 rho_frame_theta:=0.9377337733773379 eta_k:=2.898989898989899 rho_rot_mat:=1.6671111111111112 enable_rot_init:=True
# trial 3: [['max_steps', [10000]], ['rho_frame_T', [4.360717071707171]], ['rho_frame_theta', [3.258814881488149]], ['eta_k', [2.217171717171717]], ['rho_rot_mat', [0.06158585858585859]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=4.360717071707171 rho_frame_theta:=3.258814881488149 eta_k:=2.217171717171717 rho_rot_mat:=0.06158585858585859 enable_rot_init:=True
# trial 4: [['max_steps', [10000]], ['rho_frame_T', [1.8704580458045807]], ['rho_frame_theta', [2.2192939293929395]], ['eta_k', [2.090909090909091]], ['rho_rot_mat', [0.001]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=1.8704580458045807 rho_frame_theta:=2.2192939293929395 eta_k:=2.090909090909091 rho_rot_mat:=0.001 enable_rot_init:=True
# trial 5: [['max_steps', [10000]], ['rho_frame_T', [2.4643274327432745]], ['rho_frame_theta', [3.540778077807781]], ['eta_k', [0.904040404040404]], ['rho_rot_mat', [2.0003333333333333]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=2.4643274327432745 rho_frame_theta:=3.540778077807781 eta_k:=0.904040404040404 rho_rot_mat:=2.0003333333333333 enable_rot_init:=True
# trial 6: [['max_steps', [10000]], ['rho_frame_T', [3.127065706570657]], ['rho_frame_theta', [1.680819081908191]], ['eta_k', [1.1565656565656566]], ['rho_rot_mat', [2.6364848484848484]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=3.127065706570657 rho_frame_theta:=1.680819081908191 eta_k:=1.1565656565656566 rho_rot_mat:=2.6364848484848484 enable_rot_init:=True
# trial 7: [['max_steps', [10000]], ['rho_frame_T', [1.8594789478947897]], ['rho_frame_theta', [0.4666306630663067]], ['eta_k', [1.6363636363636362]], ['rho_rot_mat', [1.970040404040404]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=1.8594789478947897 rho_frame_theta:=0.4666306630663067 eta_k:=1.6363636363636362 rho_rot_mat:=1.970040404040404 enable_rot_init:=True
# trial 8: [['max_steps', [10000]], ['rho_frame_T', [1.4742124212421244]], ['rho_frame_theta', [0.7775387538753876]], ['eta_k', [1.9898989898989898]], ['rho_rot_mat', [2.333555555555556]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=1.4742124212421244 rho_frame_theta:=0.7775387538753876 eta_k:=1.9898989898989898 rho_rot_mat:=2.333555555555556 enable_rot_init:=True
# trial 9: [['max_steps', [10000]], ['rho_frame_T', [3.2124032403240323]], ['rho_frame_theta', [1.202729272927293]], ['eta_k', [2.8737373737373737]], ['rho_rot_mat', [0.5765656565656566]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=3.2124032403240323 rho_frame_theta:=1.202729272927293 eta_k:=2.8737373737373737 rho_rot_mat:=0.5765656565656566 enable_rot_init:=True
# trial 10: [['max_steps', [10000]], ['rho_frame_T', [1.7212421242124214]], ['rho_frame_theta', [0.9062936293629363]], ['eta_k', [2.191919191919192]], ['rho_rot_mat', [1.6671111111111112]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=1.7212421242124214 rho_frame_theta:=0.9062936293629363 eta_k:=2.191919191919192 rho_rot_mat:=1.6671111111111112 enable_rot_init:=True
# trial 11: [['max_steps', [10000]], ['rho_frame_T', [4.840304030403041]], ['rho_frame_theta', [2.844603460346035]], ['eta_k', [1.0303030303030303]], ['rho_rot_mat', [1.4247676767676767]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=4.840304030403041 rho_frame_theta:=2.844603460346035 eta_k:=1.0303030303030303 rho_rot_mat:=1.4247676767676767 enable_rot_init:=True
# trial 12: [['max_steps', [10000]], ['rho_frame_T', [1.3090269026902692]], ['rho_frame_theta', [2.3675117511751176]], ['eta_k', [2.797979797979798]], ['rho_rot_mat', [1.333888888888889]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=1.3090269026902692 rho_frame_theta:=2.3675117511751176 eta_k:=2.797979797979798 rho_rot_mat:=1.333888888888889 enable_rot_init:=True
# trial 13: [['max_steps', [10000]], ['rho_frame_T', [3.5223132313231322]], ['rho_frame_theta', [3.666039603960396]], ['eta_k', [0.5252525252525253]], ['rho_rot_mat', [1.243010101010101]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=3.5223132313231322 rho_frame_theta:=3.666039603960396 eta_k:=0.5252525252525253 rho_rot_mat:=1.243010101010101 enable_rot_init:=True
# trial 14: [['max_steps', [10000]], ['rho_frame_T', [4.463022302230224]], ['rho_frame_theta', [4.034837483748375]], ['eta_k', [2.116161616161616]], ['rho_rot_mat', [1.3944747474747474]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=4.463022302230224 rho_frame_theta:=4.034837483748375 eta_k:=2.116161616161616 rho_rot_mat:=1.3944747474747474 enable_rot_init:=True
# trial 15: [['max_steps', [10000]], ['rho_frame_T', [0.18965796579657968]], ['rho_frame_theta', [3.9200560056005602]], ['eta_k', [1.4343434343434343]], ['rho_rot_mat', [1.9397474747474748]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=0.18965796579657968 rho_frame_theta:=3.9200560056005602 eta_k:=1.4343434343434343 rho_rot_mat:=1.9397474747474748 enable_rot_init:=True
# trial 16: [['max_steps', [10000]], ['rho_frame_T', [4.13963796379638]], ['rho_frame_theta', [3.5053455345534554]], ['eta_k', [1.2575757575757576]], ['rho_rot_mat', [0.7583232323232324]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=4.13963796379638 rho_frame_theta:=3.5053455345534554 eta_k:=1.2575757575757576 rho_rot_mat:=0.7583232323232324 enable_rot_init:=True
# trial 17: [['max_steps', [10000]], ['rho_frame_T', [2.2282768276827682]], ['rho_frame_theta', [1.9542984298429844]], ['eta_k', [1.7121212121212122]], ['rho_rot_mat', [2.4244343434343434]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=2.2282768276827682 rho_frame_theta:=1.9542984298429844 eta_k:=1.7121212121212122 rho_rot_mat:=2.4244343434343434 enable_rot_init:=True
# trial 18: [['max_steps', [10000]], ['rho_frame_T', [1.9762566256625664]], ['rho_frame_theta', [2.5576497649764978]], ['eta_k', [2.0656565656565657]], ['rho_rot_mat', [0.9703737373737374]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=1.9762566256625664 rho_frame_theta:=2.5576497649764978 eta_k:=2.0656565656565657 rho_rot_mat:=0.9703737373737374 enable_rot_init:=True
# trial 19: [['max_steps', [10000]], ['rho_frame_T', [4.354229422942295]], ['rho_frame_theta', [0.6442924292429244]], ['eta_k', [1.4848484848484849]], ['rho_rot_mat', [1.3641818181818182]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=4.354229422942295 rho_frame_theta:=0.6442924292429244 eta_k:=1.4848484848484849 rho_rot_mat:=1.3641818181818182 enable_rot_init:=True
# trial 20: [['max_steps', [10000]], ['rho_frame_T', [0.8893259325932594]], ['rho_frame_theta', [2.789208920892089]], ['eta_k', [1.6363636363636362]], ['rho_rot_mat', [2.8485353535353535]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=0.8893259325932594 rho_frame_theta:=2.789208920892089 eta_k:=1.6363636363636362 rho_rot_mat:=2.8485353535353535 enable_rot_init:=True
# trial 21: [['max_steps', [10000]], ['rho_frame_T', [2.8470987098709872]], ['rho_frame_theta', [2.556152615261526]], ['eta_k', [1.1313131313131313]], ['rho_rot_mat', [0.6068585858585859]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=2.8470987098709872 rho_frame_theta:=2.556152615261526 eta_k:=1.1313131313131313 rho_rot_mat:=0.6068585858585859 enable_rot_init:=True
# trial 22: [['max_steps', [10000]], ['rho_frame_T', [3.9714581458145815]], ['rho_frame_theta', [0.23107910791079112]], ['eta_k', [1.3585858585858586]], ['rho_rot_mat', [1.848868686868687]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=3.9714581458145815 rho_frame_theta:=0.23107910791079112 eta_k:=1.3585858585858586 rho_rot_mat:=1.848868686868687 enable_rot_init:=True
# trial 23: [['max_steps', [10000]], ['rho_frame_T', [1.7262326232623264]], ['rho_frame_theta', [2.898999899989999]], ['eta_k', [2.696969696969697]], ['rho_rot_mat', [0.031292929292929296]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=1.7262326232623264 rho_frame_theta:=2.898999899989999 eta_k:=2.696969696969697 rho_rot_mat:=0.031292929292929296 enable_rot_init:=True
# trial 24: [['max_steps', [10000]], ['rho_frame_T', [0.7331233123312332]], ['rho_frame_theta', [3.4734063406340634]], ['eta_k', [2.5202020202020203]], ['rho_rot_mat', [0.42510101010101015]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=0.7331233123312332 rho_frame_theta:=3.4734063406340634 eta_k:=2.5202020202020203 rho_rot_mat:=0.42510101010101015 enable_rot_init:=True
# trial 25: [['max_steps', [10000]], ['rho_frame_T', [4.4914681468146815]], ['rho_frame_theta', [1.1468356835683569]], ['eta_k', [1.5101010101010102]], ['rho_rot_mat', [2.030626262626263]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=4.4914681468146815 rho_frame_theta:=1.1468356835683569 eta_k:=1.5101010101010102 rho_rot_mat:=2.030626262626263 enable_rot_init:=True
# trial 26: [['max_steps', [10000]], ['rho_frame_T', [2.0091939193919393]], ['rho_frame_theta', [0.13426342634263427]], ['eta_k', [2.9242424242424243]], ['rho_rot_mat', [0.21305050505050507]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=2.0091939193919393 rho_frame_theta:=0.13426342634263427 eta_k:=2.9242424242424243 rho_rot_mat:=0.21305050505050507 enable_rot_init:=True
# trial 27: [['max_steps', [10000]], ['rho_frame_T', [2.106009600960096]], ['rho_frame_theta', [2.06009700970097]], ['eta_k', [1.9141414141414141]], ['rho_rot_mat', [0.8794949494949496]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=2.106009600960096 rho_frame_theta:=2.06009700970097 eta_k:=1.9141414141414141 rho_rot_mat:=0.8794949494949496 enable_rot_init:=True
# trial 28: [['max_steps', [10000]], ['rho_frame_T', [2.3645174517451744]], ['rho_frame_theta', [2.195838583858386]], ['eta_k', [2.419191919191919]], ['rho_rot_mat', [2.9394141414141415]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=2.3645174517451744 rho_frame_theta:=2.195838583858386 eta_k:=2.419191919191919 rho_rot_mat:=2.9394141414141415 enable_rot_init:=True
# trial 29: [['max_steps', [10000]], ['rho_frame_T', [0.291963196319632]], ['rho_frame_theta', [3.2932493249324932]], ['eta_k', [1.7121212121212122]], ['rho_rot_mat', [0.031292929292929296]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=0.291963196319632 rho_frame_theta:=3.2932493249324932 eta_k:=1.7121212121212122 rho_rot_mat:=0.031292929292929296 enable_rot_init:=True
# trial 30: [['max_steps', [10000]], ['rho_frame_T', [0.5384938493849386]], ['rho_frame_theta', [2.3285858585858588]], ['eta_k', [0.8787878787878788]], ['rho_rot_mat', [2.7273636363636364]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=0.5384938493849386 rho_frame_theta:=2.3285858585858588 eta_k:=0.8787878787878788 rho_rot_mat:=2.7273636363636364 enable_rot_init:=True
# trial 31: [['max_steps', [10000]], ['rho_frame_T', [3.091633163316332]], ['rho_frame_theta', [4.271886188618862]], ['eta_k', [1.3585858585858586]], ['rho_rot_mat', [0.9400808080808082]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=3.091633163316332 rho_frame_theta:=4.271886188618862 eta_k:=1.3585858585858586 rho_rot_mat:=0.9400808080808082 enable_rot_init:=True
# trial 32: [['max_steps', [10000]], ['rho_frame_T', [1.0629952995299532]], ['rho_frame_theta', [2.9893279327932794]], ['eta_k', [1.3585858585858586]], ['rho_rot_mat', [0.6977373737373738]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=1.0629952995299532 rho_frame_theta:=2.9893279327932794 eta_k:=1.3585858585858586 rho_rot_mat:=0.6977373737373738 enable_rot_init:=True
# trial 33: [['max_steps', [10000]], ['rho_frame_T', [2.8585768576857684]], ['rho_frame_theta', [0.041939193919391944]], ['eta_k', [1.4848484848484849]], ['rho_rot_mat', [0.7886161616161617]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=2.8585768576857684 rho_frame_theta:=0.041939193919391944 eta_k:=1.4848484848484849 rho_rot_mat:=0.7886161616161617 enable_rot_init:=True
# trial 34: [['max_steps', [10000]], ['rho_frame_T', [0.19165416541654168]], ['rho_frame_theta', [3.9105740574057406]], ['eta_k', [1.6111111111111112]], ['rho_rot_mat', [2.272969696969697]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=0.19165416541654168 rho_frame_theta:=3.9105740574057406 eta_k:=1.6111111111111112 rho_rot_mat:=2.272969696969697 enable_rot_init:=True
# trial 35: [['max_steps', [10000]], ['rho_frame_T', [4.362214221422143]], ['rho_frame_theta', [2.619032903290329]], ['eta_k', [0.8787878787878788]], ['rho_rot_mat', [0.5462727272727274]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=4.362214221422143 rho_frame_theta:=2.619032903290329 eta_k:=0.8787878787878788 rho_rot_mat:=0.5462727272727274 enable_rot_init:=True
# trial 36: [['max_steps', [10000]], ['rho_frame_T', [0.37231023102310234]], ['rho_frame_theta', [4.804372437243725]], ['eta_k', [1.3585858585858586]], ['rho_rot_mat', [0.7280303030303031]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=0.37231023102310234 rho_frame_theta:=4.804372437243725 eta_k:=1.3585858585858586 rho_rot_mat:=0.7280303030303031 enable_rot_init:=True
# trial 37: [['max_steps', [10000]], ['rho_frame_T', [4.775926592659266]], ['rho_frame_theta', [2.243747374737474]], ['eta_k', [0.904040404040404]], ['rho_rot_mat', [0.7280303030303031]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=4.775926592659266 rho_frame_theta:=2.243747374737474 eta_k:=0.904040404040404 rho_rot_mat:=0.7280303030303031 enable_rot_init:=True
# trial 38: [['max_steps', [10000]], ['rho_frame_T', [3.463924392439244]], ['rho_frame_theta', [4.4191059105910595]], ['eta_k', [1.3585858585858586]], ['rho_rot_mat', [0.7886161616161617]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=3.463924392439244 rho_frame_theta:=4.4191059105910595 eta_k:=1.3585858585858586 rho_rot_mat:=0.7886161616161617 enable_rot_init:=True
# trial 39: [['max_steps', [10000]], ['rho_frame_T', [0.3558415841584159]], ['rho_frame_theta', [3.3870707070707073]], ['eta_k', [2.696969696969697]], ['rho_rot_mat', [1.0612525252525251]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=0.3558415841584159 rho_frame_theta:=3.3870707070707073 eta_k:=2.696969696969697 rho_rot_mat:=1.0612525252525251 enable_rot_init:=True
# trial 40: [['max_steps', [10000]], ['rho_frame_T', [1.4572447244724474]], ['rho_frame_theta', [0.045432543254325435]], ['eta_k', [2.2676767676767677]], ['rho_rot_mat', [1.3944747474747474]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=1.4572447244724474 rho_frame_theta:=0.045432543254325435 eta_k:=2.2676767676767677 rho_rot_mat:=1.3944747474747474 enable_rot_init:=True
# trial 41: [['max_steps', [10000]], ['rho_frame_T', [4.717038703870387]], ['rho_frame_theta', [0.5005660566056606]], ['eta_k', [1.308080808080808]], ['rho_rot_mat', [0.6977373737373738]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=4.717038703870387 rho_frame_theta:=0.5005660566056606 eta_k:=1.308080808080808 rho_rot_mat:=0.6977373737373738 enable_rot_init:=True
# trial 42: [['max_steps', [10000]], ['rho_frame_T', [4.686596659665967]], ['rho_frame_theta', [2.562141214121412]], ['eta_k', [0.803030303030303]], ['rho_rot_mat', [0.8189090909090909]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=4.686596659665967 rho_frame_theta:=2.562141214121412 eta_k:=0.803030303030303 rho_rot_mat:=0.8189090909090909 enable_rot_init:=True
# trial 43: [['max_steps', [10000]], ['rho_frame_T', [3.770840084008401]], ['rho_frame_theta', [4.1940344034403445]], ['eta_k', [1.4848484848484849]], ['rho_rot_mat', [1.7882828282828283]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=3.770840084008401 rho_frame_theta:=4.1940344034403445 eta_k:=1.4848484848484849 rho_rot_mat:=1.7882828282828283 enable_rot_init:=True
# trial 44: [['max_steps', [10000]], ['rho_frame_T', [2.106009600960096]], ['rho_frame_theta', [0.10881188118811881]], ['eta_k', [1.4848484848484849]], ['rho_rot_mat', [1.7882828282828283]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=2.106009600960096 rho_frame_theta:=0.10881188118811881 eta_k:=1.4848484848484849 rho_rot_mat:=1.7882828282828283 enable_rot_init:=True
# trial 45: [['max_steps', [10000]], ['rho_frame_T', [1.908884888488849]], ['rho_frame_theta', [4.542371237123713]], ['eta_k', [2.0404040404040407]], ['rho_rot_mat', [0.18275757575757579]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=1.908884888488849 rho_frame_theta:=4.542371237123713 eta_k:=2.0404040404040407 rho_rot_mat:=0.18275757575757579 enable_rot_init:=True
# trial 46: [['max_steps', [10000]], ['rho_frame_T', [0.9512081208120813]], ['rho_frame_theta', [4.367703770377038]], ['eta_k', [2.595959595959596]], ['rho_rot_mat', [1.243010101010101]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=0.9512081208120813 rho_frame_theta:=4.367703770377038 eta_k:=2.595959595959596 rho_rot_mat:=1.243010101010101 enable_rot_init:=True
# trial 47: [['max_steps', [10000]], ['rho_frame_T', [3.2413481348134816]], ['rho_frame_theta', [1.8325302530253027]], ['eta_k', [0.6262626262626263]], ['rho_rot_mat', [2.6364848484848484]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=3.2413481348134816 rho_frame_theta:=1.8325302530253027 eta_k:=0.6262626262626263 rho_rot_mat:=2.6364848484848484 enable_rot_init:=True
# trial 48: [['max_steps', [10000]], ['rho_frame_T', [1.8185568556855687]], ['rho_frame_theta', [4.054300430043004]], ['eta_k', [1.7373737373737375]], ['rho_rot_mat', [0.9400808080808082]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=1.8185568556855687 rho_frame_theta:=4.054300430043004 eta_k:=1.7373737373737375 rho_rot_mat:=0.9400808080808082 enable_rot_init:=True
# trial 49: [['max_steps', [10000]], ['rho_frame_T', [1.8125682568256827]], ['rho_frame_theta', [3.980940094009401]], ['eta_k', [2.595959595959596]], ['rho_rot_mat', [1.5156464646464647]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=1.8125682568256827 rho_frame_theta:=3.980940094009401 eta_k:=2.595959595959596 rho_rot_mat:=1.5156464646464647 enable_rot_init:=True
# trial 50: [['max_steps', [10000]], ['rho_frame_T', [2.741799179917992]], ['rho_frame_theta', [2.273191319131913]], ['eta_k', [2.621212121212121]], ['rho_rot_mat', [2.878828282828283]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=2.741799179917992 rho_frame_theta:=2.273191319131913 eta_k:=2.621212121212121 rho_rot_mat:=2.878828282828283 enable_rot_init:=True
# trial 51: [['max_steps', [10000]], ['rho_frame_T', [4.667133713371338]], ['rho_frame_theta', [2.7208390839083907]], ['eta_k', [1.8636363636363635]], ['rho_rot_mat', [0.9400808080808082]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=4.667133713371338 rho_frame_theta:=2.7208390839083907 eta_k:=1.8636363636363635 rho_rot_mat:=0.9400808080808082 enable_rot_init:=True
# trial 52: [['max_steps', [10000]], ['rho_frame_T', [0.43868386838683876]], ['rho_frame_theta', [1.7931053105310533]], ['eta_k', [2.974747474747475]], ['rho_rot_mat', [2.6061919191919194]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=0.43868386838683876 rho_frame_theta:=1.7931053105310533 eta_k:=2.974747474747475 rho_rot_mat:=2.6061919191919194 enable_rot_init:=True
# trial 53: [['max_steps', [10000]], ['rho_frame_T', [1.5326012601260128]], ['rho_frame_theta', [0.286972697269727]], ['eta_k', [2.621212121212121]], ['rho_rot_mat', [1.4853535353535354]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=1.5326012601260128 rho_frame_theta:=0.286972697269727 eta_k:=2.621212121212121 rho_rot_mat:=1.4853535353535354 enable_rot_init:=True
# trial 54: [['max_steps', [10000]], ['rho_frame_T', [4.640684068406841]], ['rho_frame_theta', [0.1851665166516652]], ['eta_k', [2.898989898989899]], ['rho_rot_mat', [1.3641818181818182]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=4.640684068406841 rho_frame_theta:=0.1851665166516652 eta_k:=2.898989898989899 rho_rot_mat:=1.3641818181818182 enable_rot_init:=True
# trial 55: [['max_steps', [10000]], ['rho_frame_T', [2.687901790179018]], ['rho_frame_theta', [4.815850585058506]], ['eta_k', [1.9393939393939394]], ['rho_rot_mat', [2.6061919191919194]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=2.687901790179018 rho_frame_theta:=4.815850585058506 eta_k:=1.9393939393939394 rho_rot_mat:=2.6061919191919194 enable_rot_init:=True
# trial 56: [['max_steps', [10000]], ['rho_frame_T', [0.9681758175817583]], ['rho_frame_theta', [4.165089508950896]], ['eta_k', [1.6616161616161615]], ['rho_rot_mat', [2.242676767676768]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=0.9681758175817583 rho_frame_theta:=4.165089508950896 eta_k:=1.6616161616161615 rho_rot_mat:=2.242676767676768 enable_rot_init:=True
# trial 57: [['max_steps', [10000]], ['rho_frame_T', [2.0426302630263025]], ['rho_frame_theta', [2.9254495449544957]], ['eta_k', [0.6262626262626263]], ['rho_rot_mat', [0.36451515151515157]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=2.0426302630263025 rho_frame_theta:=2.9254495449544957 eta_k:=0.6262626262626263 rho_rot_mat:=0.36451515151515157 enable_rot_init:=True
# trial 58: [['max_steps', [10000]], ['rho_frame_T', [0.37979597959795985]], ['rho_frame_theta', [3.244841484148415]], ['eta_k', [1.106060606060606]], ['rho_rot_mat', [1.0309595959595959]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=0.37979597959795985 rho_frame_theta:=3.244841484148415 eta_k:=1.106060606060606 rho_rot_mat:=1.0309595959595959 enable_rot_init:=True
# trial 59: [['max_steps', [10000]], ['rho_frame_T', [1.7012801280128014]], ['rho_frame_theta', [1.2351675167516754]], ['eta_k', [2.9242424242424243]], ['rho_rot_mat', [2.878828282828283]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=1.7012801280128014 rho_frame_theta:=1.2351675167516754 eta_k:=2.9242424242424243 rho_rot_mat:=2.878828282828283 enable_rot_init:=True
# trial 60: [['max_steps', [10000]], ['rho_frame_T', [3.083648364836484]], ['rho_frame_theta', [4.144129412941294]], ['eta_k', [1.5858585858585859]], ['rho_rot_mat', [1.4853535353535354]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=3.083648364836484 rho_frame_theta:=4.144129412941294 eta_k:=1.5858585858585859 rho_rot_mat:=1.4853535353535354 enable_rot_init:=True
# trial 61: [['max_steps', [10000]], ['rho_frame_T', [4.237451745174518]], ['rho_frame_theta', [0.4416781678167817]], ['eta_k', [2.797979797979798]], ['rho_rot_mat', [0.5765656565656566]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=4.237451745174518 rho_frame_theta:=0.4416781678167817 eta_k:=2.797979797979798 rho_rot_mat:=0.5765656565656566 enable_rot_init:=True
# trial 62: [['max_steps', [10000]], ['rho_frame_T', [4.53937693769377]], ['rho_frame_theta', [3.8616671667166718]], ['eta_k', [2.242424242424242]], ['rho_rot_mat', [0.24334343434343436]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=4.53937693769377 rho_frame_theta:=3.8616671667166718 eta_k:=2.242424242424242 rho_rot_mat:=0.24334343434343436 enable_rot_init:=True
# trial 63: [['max_steps', [10000]], ['rho_frame_T', [2.581105110511051]], ['rho_frame_theta', [4.525403540354036]], ['eta_k', [3.0]], ['rho_rot_mat', [0.4856868686868687]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=2.581105110511051 rho_frame_theta:=4.525403540354036 eta_k:=3.0 rho_rot_mat:=0.4856868686868687 enable_rot_init:=True
# trial 64: [['max_steps', [10000]], ['rho_frame_T', [2.4653255325532553]], ['rho_frame_theta', [1.716750675067507]], ['eta_k', [2.419191919191919]], ['rho_rot_mat', [3.0]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=2.4653255325532553 rho_frame_theta:=1.716750675067507 eta_k:=2.419191919191919 rho_rot_mat:=3.0 enable_rot_init:=True
# trial 65: [['max_steps', [10000]], ['rho_frame_T', [0.7256375637563757]], ['rho_frame_theta', [1.2291789178917893]], ['eta_k', [0.7525252525252526]], ['rho_rot_mat', [2.878828282828283]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=0.7256375637563757 rho_frame_theta:=1.2291789178917893 eta_k:=0.7525252525252526 rho_rot_mat:=2.878828282828283 enable_rot_init:=True
# trial 66: [['max_steps', [10000]], ['rho_frame_T', [1.680819081908191]], ['rho_frame_theta', [3.6385918591859188]], ['eta_k', [0.5505050505050505]], ['rho_rot_mat', [1.3035959595959596]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=1.680819081908191 rho_frame_theta:=3.6385918591859188 eta_k:=0.5505050505050505 rho_rot_mat:=1.3035959595959596 enable_rot_init:=True
# trial 67: [['max_steps', [10000]], ['rho_frame_T', [1.1638033803380339]], ['rho_frame_theta', [3.8292289228922893]], ['eta_k', [1.308080808080808]], ['rho_rot_mat', [1.8185757575757575]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=1.1638033803380339 rho_frame_theta:=3.8292289228922893 eta_k:=1.308080808080808 rho_rot_mat:=1.8185757575757575 enable_rot_init:=True
# trial 68: [['max_steps', [10000]], ['rho_frame_T', [0.1257795779577958]], ['rho_frame_theta', [1.6893029302930294]], ['eta_k', [1.4848484848484849]], ['rho_rot_mat', [1.4853535353535354]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=0.1257795779577958 rho_frame_theta:=1.6893029302930294 eta_k:=1.4848484848484849 rho_rot_mat:=1.4853535353535354 enable_rot_init:=True
# trial 69: [['max_steps', [10000]], ['rho_frame_T', [0.6383038303830384]], ['rho_frame_theta', [2.749284928492849]], ['eta_k', [1.5353535353535352]], ['rho_rot_mat', [0.8189090909090909]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=0.6383038303830384 rho_frame_theta:=2.749284928492849 eta_k:=1.5353535353535352 rho_rot_mat:=0.8189090909090909 enable_rot_init:=True
# trial 70: [['max_steps', [10000]], ['rho_frame_T', [0.11030903090309031]], ['rho_frame_theta', [1.926850685068507]], ['eta_k', [1.6111111111111112]], ['rho_rot_mat', [2.969707070707071]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=0.11030903090309031 rho_frame_theta:=1.926850685068507 eta_k:=1.6111111111111112 rho_rot_mat:=2.969707070707071 enable_rot_init:=True
# trial 71: [['max_steps', [10000]], ['rho_frame_T', [1.100923092309231]], ['rho_frame_theta', [3.2997369736973696]], ['eta_k', [1.1565656565656566]], ['rho_rot_mat', [2.3032626262626263]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=1.100923092309231 rho_frame_theta:=3.2997369736973696 eta_k:=1.1565656565656566 rho_rot_mat:=2.3032626262626263 enable_rot_init:=True
# trial 72: [['max_steps', [10000]], ['rho_frame_T', [1.0590029002900292]], ['rho_frame_theta', [1.602967296729673]], ['eta_k', [1.7373737373737375]], ['rho_rot_mat', [1.9397474747474748]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=1.0590029002900292 rho_frame_theta:=1.602967296729673 eta_k:=1.7373737373737375 rho_rot_mat:=1.9397474747474748 enable_rot_init:=True
# trial 73: [['max_steps', [10000]], ['rho_frame_T', [2.2841704170417043]], ['rho_frame_theta', [4.653659365936594]], ['eta_k', [0.8535353535353536]], ['rho_rot_mat', [1.243010101010101]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=2.2841704170417043 rho_frame_theta:=4.653659365936594 eta_k:=0.8535353535353536 rho_rot_mat:=1.243010101010101 enable_rot_init:=True
# trial 74: [['max_steps', [10000]], ['rho_frame_T', [3.460930093009301]], ['rho_frame_theta', [2.9803450345034506]], ['eta_k', [0.5505050505050505]], ['rho_rot_mat', [1.243010101010101]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=3.460930093009301 rho_frame_theta:=2.9803450345034506 eta_k:=0.5505050505050505 rho_rot_mat:=1.243010101010101 enable_rot_init:=True
# trial 75: [['max_steps', [10000]], ['rho_frame_T', [4.095222522252225]], ['rho_frame_theta', [0.3578377837783779]], ['eta_k', [1.4848484848484849]], ['rho_rot_mat', [0.5765656565656566]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=4.095222522252225 rho_frame_theta:=0.3578377837783779 eta_k:=1.4848484848484849 rho_rot_mat:=0.5765656565656566 enable_rot_init:=True
# trial 76: [['max_steps', [10000]], ['rho_frame_T', [1.715752575257526]], ['rho_frame_theta', [4.018368836883688]], ['eta_k', [2.5202020202020203]], ['rho_rot_mat', [0.39480808080808083]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=1.715752575257526 rho_frame_theta:=4.018368836883688 eta_k:=2.5202020202020203 rho_rot_mat:=0.39480808080808083 enable_rot_init:=True
# trial 77: [['max_steps', [10000]], ['rho_frame_T', [0.6837173717371738]], ['rho_frame_theta', [4.512927292729273]], ['eta_k', [0.6262626262626263]], ['rho_rot_mat', [1.7276969696969697]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=0.6837173717371738 rho_frame_theta:=4.512927292729273 eta_k:=0.6262626262626263 rho_rot_mat:=1.7276969696969697 enable_rot_init:=True
# trial 78: [['max_steps', [10000]], ['rho_frame_T', [4.175569556955696]], ['rho_frame_theta', [3.241847184718472]], ['eta_k', [0.6515151515151515]], ['rho_rot_mat', [1.4853535353535354]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=4.175569556955696 rho_frame_theta:=3.241847184718472 eta_k:=0.6515151515151515 rho_rot_mat:=1.4853535353535354 enable_rot_init:=True
# trial 79: [['max_steps', [10000]], ['rho_frame_T', [1.4866886688668868]], ['rho_frame_theta', [3.8312251225122513]], ['eta_k', [1.3585858585858586]], ['rho_rot_mat', [2.060919191919192]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=1.4866886688668868 rho_frame_theta:=3.8312251225122513 eta_k:=1.3585858585858586 rho_rot_mat:=2.060919191919192 enable_rot_init:=True
# trial 80: [['max_steps', [10000]], ['rho_frame_T', [4.494961496149616]], ['rho_frame_theta', [2.1264706470647066]], ['eta_k', [1.7878787878787878]], ['rho_rot_mat', [0.8189090909090909]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=4.494961496149616 rho_frame_theta:=2.1264706470647066 eta_k:=1.7878787878787878 rho_rot_mat:=0.8189090909090909 enable_rot_init:=True
# trial 81: [['max_steps', [10000]], ['rho_frame_T', [4.946601660166017]], ['rho_frame_theta', [4.710551055105511]], ['eta_k', [1.9393939393939394]], ['rho_rot_mat', [1.0006666666666666]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=4.946601660166017 rho_frame_theta:=4.710551055105511 eta_k:=1.9393939393939394 rho_rot_mat:=1.0006666666666666 enable_rot_init:=True
# trial 82: [['max_steps', [10000]], ['rho_frame_T', [1.7990939093909393]], ['rho_frame_theta', [2.9354305430543053]], ['eta_k', [0.7272727272727273]], ['rho_rot_mat', [0.9097878787878788]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=1.7990939093909393 rho_frame_theta:=2.9354305430543053 eta_k:=0.7272727272727273 rho_rot_mat:=0.9097878787878788 enable_rot_init:=True
# trial 83: [['max_steps', [10000]], ['rho_frame_T', [3.653064306430643]], ['rho_frame_theta', [0.43419241924192425]], ['eta_k', [2.1414141414141414]], ['rho_rot_mat', [2.969707070707071]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=3.653064306430643 rho_frame_theta:=0.43419241924192425 eta_k:=2.1414141414141414 rho_rot_mat:=2.969707070707071 enable_rot_init:=True
# trial 84: [['max_steps', [10000]], ['rho_frame_T', [2.0595979597959797]], ['rho_frame_theta', [0.1143014301430143]], ['eta_k', [2.8737373737373737]], ['rho_rot_mat', [0.06158585858585859]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=2.0595979597959797 rho_frame_theta:=0.1143014301430143 eta_k:=2.8737373737373737 rho_rot_mat:=0.06158585858585859 enable_rot_init:=True
# ...
# trial 758: [['max_steps', [10000]], ['rho_frame_T', [2.1254725472547253]], ['rho_frame_theta', [4.617727772777278]], ['eta_k', [2.1414141414141414]], ['rho_rot_mat', [2.030626262626263]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=2.1254725472547253 rho_frame_theta:=4.617727772777278 eta_k:=2.1414141414141414 rho_rot_mat:=2.030626262626263 enable_rot_init:=True
# trial 759: [['max_steps', [10000]], ['rho_frame_T', [3.1285628562856287]], ['rho_frame_theta', [1.8529912991299131]], ['eta_k', [0.601010101010101]], ['rho_rot_mat', [0.39480808080808083]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=3.1285628562856287 rho_frame_theta:=1.8529912991299131 eta_k:=0.601010101010101 rho_rot_mat:=0.39480808080808083 enable_rot_init:=True
# trial 760: [['max_steps', [10000]], ['rho_frame_T', [0.9831473147314732]], ['rho_frame_theta', [2.8625692569256924]], ['eta_k', [1.5101010101010102]], ['rho_rot_mat', [2.787949494949495]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=0.9831473147314732 rho_frame_theta:=2.8625692569256924 eta_k:=1.5101010101010102 rho_rot_mat:=2.787949494949495 enable_rot_init:=True
# trial 761: [['max_steps', [10000]], ['rho_frame_T', [3.0686768676867686]], ['rho_frame_theta', [3.2573177317731776]], ['eta_k', [2.8484848484848486]], ['rho_rot_mat', [2.0912121212121213]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=3.0686768676867686 rho_frame_theta:=3.2573177317731776 eta_k:=2.8484848484848486 rho_rot_mat:=2.0912121212121213 enable_rot_init:=True
# trial 762: [['max_steps', [10000]], ['rho_frame_T', [3.0172747274727474]], ['rho_frame_theta', [2.2921552155215523]], ['eta_k', [1.6111111111111112]], ['rho_rot_mat', [0.9400808080808082]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=3.0172747274727474 rho_frame_theta:=2.2921552155215523 eta_k:=1.6111111111111112 rho_rot_mat:=0.9400808080808082 enable_rot_init:=True
# trial 763: [['max_steps', [10000]], ['rho_frame_T', [3.8696519651965198]], ['rho_frame_theta', [1.7327202720272028]], ['eta_k', [0.8535353535353536]], ['rho_rot_mat', [1.7882828282828283]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=3.8696519651965198 rho_frame_theta:=1.7327202720272028 eta_k:=0.8535353535353536 rho_rot_mat:=1.7882828282828283 enable_rot_init:=True
# trial 764: [['max_steps', [10000]], ['rho_frame_T', [0.7830283028302831]], ['rho_frame_theta', [3.3411581158115813]], ['eta_k', [2.217171717171717]], ['rho_rot_mat', [0.12217171717171718]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=0.7830283028302831 rho_frame_theta:=3.3411581158115813 eta_k:=2.217171717171717 rho_rot_mat:=0.12217171717171718 enable_rot_init:=True
# trial 765: [['max_steps', [10000]], ['rho_frame_T', [1.703775377537754]], ['rho_frame_theta', [0.308930893089309]], ['eta_k', [1.308080808080808]], ['rho_rot_mat', [1.0915454545454546]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=1.703775377537754 rho_frame_theta:=0.308930893089309 eta_k:=1.308080808080808 rho_rot_mat:=1.0915454545454546 enable_rot_init:=True
# trial 766: [['max_steps', [10000]], ['rho_frame_T', [1.947810781078108]], ['rho_frame_theta', [3.548762876287629]], ['eta_k', [2.4444444444444446]], ['rho_rot_mat', [1.3641818181818182]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=1.947810781078108 rho_frame_theta:=3.548762876287629 eta_k:=2.4444444444444446 rho_rot_mat:=1.3641818181818182 enable_rot_init:=True
# trial 767: [['max_steps', [10000]], ['rho_frame_T', [0.8703620362036204]], ['rho_frame_theta', [2.2247834783478346]], ['eta_k', [0.8282828282828283]], ['rho_rot_mat', [2.9091212121212124]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=0.8703620362036204 rho_frame_theta:=2.2247834783478346 eta_k:=0.8282828282828283 rho_rot_mat:=2.9091212121212124 enable_rot_init:=True
# trial 768: [['max_steps', [10000]], ['rho_frame_T', [0.7545824582458247]], ['rho_frame_theta', [3.260811081108111]], ['eta_k', [1.3585858585858586]], ['rho_rot_mat', [2.272969696969697]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=0.7545824582458247 rho_frame_theta:=3.260811081108111 eta_k:=1.3585858585858586 rho_rot_mat:=2.272969696969697 enable_rot_init:=True
# trial 769: [['max_steps', [10000]], ['rho_frame_T', [1.601969196919692]], ['rho_frame_theta', [1.4203150315031505]], ['eta_k', [0.9797979797979798]], ['rho_rot_mat', [0.9703737373737374]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=1.601969196919692 rho_frame_theta:=1.4203150315031505 eta_k:=0.9797979797979798 rho_rot_mat:=0.9703737373737374 enable_rot_init:=True
# trial 770: [['max_steps', [10000]], ['rho_frame_T', [4.745484548454845]], ['rho_frame_theta', [1.083955395539554]], ['eta_k', [0.6767676767676768]], ['rho_rot_mat', [0.12217171717171718]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=4.745484548454845 rho_frame_theta:=1.083955395539554 eta_k:=0.6767676767676768 rho_rot_mat:=0.12217171717171718 enable_rot_init:=True
# trial 771: [['max_steps', [10000]], ['rho_frame_T', [2.423405340534053]], ['rho_frame_theta', [0.8523962396239625]], ['eta_k', [2.3939393939393936]], ['rho_rot_mat', [1.6368181818181817]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=2.423405340534053 rho_frame_theta:=0.8523962396239625 eta_k:=2.3939393939393936 rho_rot_mat:=1.6368181818181817 enable_rot_init:=True
# trial 772: [['max_steps', [10000]], ['rho_frame_T', [1.4592409240924094]], ['rho_frame_theta', [0.5205280528052806]], ['eta_k', [1.3838383838383839]], ['rho_rot_mat', [1.3035959595959596]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=1.4592409240924094 rho_frame_theta:=0.5205280528052806 eta_k:=1.3838383838383839 rho_rot_mat:=1.3035959595959596 enable_rot_init:=True
# trial 773: [['max_steps', [10000]], ['rho_frame_T', [1.7322212221222124]], ['rho_frame_theta', [1.0440314031403142]], ['eta_k', [0.5252525252525253]], ['rho_rot_mat', [1.3944747474747474]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=1.7322212221222124 rho_frame_theta:=1.0440314031403142 eta_k:=0.5252525252525253 rho_rot_mat:=1.3944747474747474 enable_rot_init:=True
# trial 774: [['max_steps', [10000]], ['rho_frame_T', [2.407934793479348]], ['rho_frame_theta', [2.9583868386838685]], ['eta_k', [2.4696969696969697]], ['rho_rot_mat', [1.1521313131313131]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=2.407934793479348 rho_frame_theta:=2.9583868386838685 eta_k:=2.4696969696969697 rho_rot_mat:=1.1521313131313131 enable_rot_init:=True
# trial 775: [['max_steps', [10000]], ['rho_frame_T', [1.3833853385338535]], ['rho_frame_theta', [2.8550835083508352]], ['eta_k', [2.217171717171717]], ['rho_rot_mat', [2.030626262626263]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=1.3833853385338535 rho_frame_theta:=2.8550835083508352 eta_k:=2.217171717171717 rho_rot_mat:=2.030626262626263 enable_rot_init:=True
# trial 776: [['max_steps', [10000]], ['rho_frame_T', [3.6989768976897692]], ['rho_frame_theta', [2.898001800180018]], ['eta_k', [2.823232323232323]], ['rho_rot_mat', [2.57589898989899]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=3.6989768976897692 rho_frame_theta:=2.898001800180018 eta_k:=2.823232323232323 rho_rot_mat:=2.57589898989899 enable_rot_init:=True
# trial 777: [['max_steps', [10000]], ['rho_frame_T', [3.9744524452445247]], ['rho_frame_theta', [2.932935293529353]], ['eta_k', [2.7727272727272725]], ['rho_rot_mat', [2.969707070707071]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=3.9744524452445247 rho_frame_theta:=2.932935293529353 eta_k:=2.7727272727272725 rho_rot_mat:=2.969707070707071 enable_rot_init:=True
# trial 778: [['max_steps', [10000]], ['rho_frame_T', [1.9153725372537256]], ['rho_frame_theta', [2.3066276627662767]], ['eta_k', [1.2070707070707072]], ['rho_rot_mat', [1.6974040404040405]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=1.9153725372537256 rho_frame_theta:=2.3066276627662767 eta_k:=1.2070707070707072 rho_rot_mat:=1.6974040404040405 enable_rot_init:=True
# trial 779: [['max_steps', [10000]], ['rho_frame_T', [2.452849284928493]], ['rho_frame_theta', [2.807174717471747]], ['eta_k', [1.9646464646464645]], ['rho_rot_mat', [0.0918787878787879]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=2.452849284928493 rho_frame_theta:=2.807174717471747 eta_k:=1.9646464646464645 rho_rot_mat:=0.0918787878787879 enable_rot_init:=True
# trial 780: [['max_steps', [10000]], ['rho_frame_T', [2.9563906390639065]], ['rho_frame_theta', [2.4832913291329133]], ['eta_k', [2.5707070707070705]], ['rho_rot_mat', [0.15246464646464647]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=2.9563906390639065 rho_frame_theta:=2.4832913291329133 eta_k:=2.5707070707070705 rho_rot_mat:=0.15246464646464647 enable_rot_init:=True
# trial 781: [['max_steps', [10000]], ['rho_frame_T', [4.497955795579558]], ['rho_frame_theta', [4.942609260926093]], ['eta_k', [2.0404040404040407]], ['rho_rot_mat', [2.4244343434343434]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=4.497955795579558 rho_frame_theta:=4.942609260926093 eta_k:=2.0404040404040407 rho_rot_mat:=2.4244343434343434 enable_rot_init:=True
# trial 782: [['max_steps', [10000]], ['rho_frame_T', [2.9384248424842485]], ['rho_frame_theta', [3.0941284128412843]], ['eta_k', [2.217171717171717]], ['rho_rot_mat', [0.8189090909090909]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=2.9384248424842485 rho_frame_theta:=3.0941284128412843 eta_k:=2.217171717171717 rho_rot_mat:=0.8189090909090909 enable_rot_init:=True
# trial 783: [['max_steps', [10000]], ['rho_frame_T', [0.1716921692169217]], ['rho_frame_theta', [0.20263326332633266]], ['eta_k', [1.106060606060606]], ['rho_rot_mat', [2.6061919191919194]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=0.1716921692169217 rho_frame_theta:=0.20263326332633266 eta_k:=1.106060606060606 rho_rot_mat:=2.6061919191919194 enable_rot_init:=True
# trial 784: [['max_steps', [10000]], ['rho_frame_T', [1.117890789078908]], ['rho_frame_theta', [3.155012501250125]], ['eta_k', [2.090909090909091]], ['rho_rot_mat', [0.2736363636363637]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=1.117890789078908 rho_frame_theta:=3.155012501250125 eta_k:=2.090909090909091 rho_rot_mat:=0.2736363636363637 enable_rot_init:=True
# trial 785: [['max_steps', [10000]], ['rho_frame_T', [4.088235823582359]], ['rho_frame_theta', [2.7827212721272128]], ['eta_k', [2.898989898989899]], ['rho_rot_mat', [2.242676767676768]], ['enable_rot_init', ['True']]]
# roslaunch d2pgo d2pgo_test_multi.launch  g2o_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/input/ output_path:=/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/ agent_num:=5 max_steps:=10000 rho_frame_T:=4.088235823582359 rho_frame_theta:=2.7827212721272128 eta_k:=2.898989898989899 rho_rot_mat:=2.242676767676768 enable_rot_init:=True

# %%
#Show the convergence of the results
intput_data = "/home/xuhao/data/d2slam/pgo/torus3D/input/"
gt_data = "/home/xuhao/data/d2slam/pgo/torus3D/groundtruth.g2o"
output_data = "/home/xuhao/data/d2slam/pgo/torus3D/output/"
agent_num = 5
params = [
    ["max_steps", np.logspace(0, 2, 10, base=10, dtype=int)],
    ["debug_rot_init_only", ["true"]]
]
fixed_param = {
    "debug_rot_init_only":"true"
}
ret = grid_search(intput_data, output_data, gt_data, agent_num, params, fixed_param)
print_res_to_table(ret, "max_steps")
# Out:
# '<table>\n<tbody>\n<tr><td>max_steps</td><td>debug_rot_init_only</td><td>ATE_T  </td><td>ATE_rot</td></tr>\n<tr><td>1        </td><td>true               </td><td>16.115m</td><td>76.939 </td></tr>\n<tr><td>1        </td><td>true               </td><td>11.555m</td><td>118.155</td></tr>\n<tr><td>2        </td><td>true               </td><td>16.115m</td><td>45.946 </td></tr>\n<tr><td>4        </td><td>true               </td><td>16.115m</td><td>4.853  </td></tr>\n<tr><td>7        </td><td>true               </td><td>16.115m</td><td>4.732  </td></tr>\n<tr><td>12       </td><td>true               </td><td>16.114m</td><td>4.639  </td></tr>\n<tr><td>21       </td><td>true               </td><td>16.114m</td><td>4.289  </td></tr>\n<tr><td>35       </td><td>true               </td><td>16.112m</td><td>3.784  </td></tr>\n<tr><td>59       </td><td>true               </td><td>16.110m</td><td>3.402  </td></tr>\n<tr><td>100      </td><td>true               </td><td>16.106m</td><td>3.200  </td></tr>\n</tbody>\n</table>'

# %%
intput_data = "/home/xuhao/data/d2slam/pgo/torus3D/input/"
gt_data = "/home/xuhao/data/d2slam/pgo/torus3D/groundtruth.g2o"
output_data = "/home/xuhao/data/d2slam/pgo/torus3D/output/"
agent_num = 5
params = [
    ["rho_rot_mat", np.logspace(-3, 1, 10, base=10)]
]
fixed_param = {
    "debug_rot_init_only":"true",
    "max_steps": 20
}
ret = grid_search(intput_data, output_data, gt_data, agent_num, params, fixed_param)
print_res_to_table(ret, "ATE_rot")

# %%
def search_function(param):
    pg_output, _, _ = call_d2pgo_opti(input_data, output_data, agent_num = agent_num, max_steps=100, enable_rot_init=True, 
        eta_k=param['eta_k'], rho_frame_theta=param['rho_frame_theta'], rho_frame_T=param['rho_frame_T'])
    return pg_output.evaluate_cost()
# input_data = "/home/xuhao/data/d2slam/pgo/tum_corr_5/input"
# output_data = "/home/xuhao/data/d2slam/pgo/tum_corr_5/searching-output/"

input_data = "/home/xuhao/data/d2slam/pgo/parking-garage/input"
output_data = "/home/xuhao/data/d2slam/pgo/parking-garage/searching-output/"

agent_num = 5
from hyperopt import hp, fmin, tpe
space = {
    "rho_frame_T": hp.uniform("rho_frame_T", 0.0, 10.0),
    "rho_frame_theta": hp.uniform("rho_frame_theta", 0.0, 10.0),
    "eta_k": hp.uniform("eta_k", 0, 5.0),
}

best = fmin(search_function, space, algo=tpe.suggest, max_evals=100)
print(best)
# Out:
#  11%|█         | 11/100 [06:17<50:51, 34.29s/trial, best loss: 58.33438399261962]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb 单元格 7 in <cell line: 19>()
#      <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#X11sZmlsZQ%3D%3D?line=11'>12</a> from hyperopt import hp, fmin, tpe
#      <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#X11sZmlsZQ%3D%3D?line=12'>13</a> space = {
#      <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#X11sZmlsZQ%3D%3D?line=13'>14</a>     "rho_frame_T": hp.uniform("rho_frame_T", 0.0, 10.0),
#      <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#X11sZmlsZQ%3D%3D?line=14'>15</a>     "rho_frame_theta": hp.uniform("rho_frame_theta", 0.0, 10.0),
#      <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#X11sZmlsZQ%3D%3D?line=15'>16</a>     "eta_k": hp.uniform("eta_k", 0, 5.0),
#      <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#X11sZmlsZQ%3D%3D?line=16'>17</a> }
# ---> <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#X11sZmlsZQ%3D%3D?line=18'>19</a> best = fmin(search_function, space, algo=tpe.suggest, max_evals=100)
#      <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#X11sZmlsZQ%3D%3D?line=19'>20</a> print(best)
#
# File ~/anaconda3/lib/python3.8/site-packages/hyperopt/fmin.py:586, in fmin(fn, space, algo, max_evals, timeout, loss_threshold, trials, rstate, allow_trials_fmin, pass_expr_memo_ctrl, catch_eval_exceptions, verbose, return_argmin, points_to_evaluate, max_queue_len, show_progressbar, early_stop_fn, trials_save_file)
#     583 rval.catch_eval_exceptions = catch_eval_exceptions
#     585 # next line is where the fmin is actually executed
# --> 586 rval.exhaust()
#     588 if return_argmin:
#     589     if len(trials.trials) == 0:
#
# File ~/anaconda3/lib/python3.8/site-packages/hyperopt/fmin.py:364, in FMinIter.exhaust(self)
#     362 def exhaust(self):
#     363     n_done = len(self.trials)
# --> 364     self.run(self.max_evals - n_done, block_until_done=self.asynchronous)
#     365     self.trials.refresh()
#     366     return self
#
# File ~/anaconda3/lib/python3.8/site-packages/hyperopt/fmin.py:300, in FMinIter.run(self, N, block_until_done)
#     297     time.sleep(self.poll_interval_secs)
#     298 else:
#     299     # -- loop over trials and do the jobs directly
# --> 300     self.serial_evaluate()
#     302 self.trials.refresh()
#     303 if self.trials_save_file != "":
#
# File ~/anaconda3/lib/python3.8/site-packages/hyperopt/fmin.py:178, in FMinIter.serial_evaluate(self, N)
#     176 ctrl = base.Ctrl(self.trials, current_trial=trial)
#     177 try:
# --> 178     result = self.domain.evaluate(spec, ctrl)
#     179 except Exception as e:
#     180     logger.error("job exception: %s" % str(e))
#
# File ~/anaconda3/lib/python3.8/site-packages/hyperopt/base.py:892, in Domain.evaluate(self, config, ctrl, attach_attachments)
#     883 else:
#     884     # -- the "work" of evaluating `config` can be written
#     885     #    either into the pyll part (self.expr)
#     886     #    or the normal Python part (self.fn)
#     887     pyll_rval = pyll.rec_eval(
#     888         self.expr,
#     889         memo=memo,
#     890         print_node_on_error=self.rec_eval_print_node_on_error,
#     891     )
# --> 892     rval = self.fn(pyll_rval)
#     894 if isinstance(rval, (float, int, np.number)):
#     895     dict_rval = {"loss": float(rval), "status": STATUS_OK}
#
# /home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb 单元格 7 in search_function(param)
#       <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> def search_function(param):
# ----> <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a>     pg_output, _, _ = call_d2pgo_opti(input_data, output_data, agent_num = agent_num, max_steps=100, enable_rot_init=True,
#       <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#X11sZmlsZQ%3D%3D?line=2'>3</a>         eta_k=param['eta_k'], rho_frame_theta=param['rho_frame_theta'], rho_frame_T=param['rho_frame_T'])
#       <a href='vscode-notebook-cell:/home/xuhao/d2slam_ws/src/D2SLAM/d2pgo/scripts/notebooks/d2pgo_param_searching.ipynb#X11sZmlsZQ%3D%3D?line=3'>4</a>     return pg_output.evaluate_cost()
#
# File ~/d2slam_ws/src/D2SLAM/d2pgo/scripts/simulate_utils.py:109, in call_d2pgo_opti(g2o_folder, output_folder, agent_num, ignore_infor, simulate_delay_ms, max_steps, enable_rot_init, enable_linear_pose6d_solver, eta_k, rho_frame_theta, rho_frame_T)
#     104 command = f"roslaunch d2pgo d2pgo_test_multi.launch agent_num:={agent_num} g2o_path:={g2o_folder} \
#     105     output_path:={output_folder} enable_rot_init:={enable_rot_init} max_steps:={max_steps} ignore_infor:={ignore_infor} \
#     106     eta_k:={eta_k} rho_frame_theta:={rho_frame_theta} rho_frame_T:={rho_frame_T} simulate_delay_ms:={simulate_delay_ms} \
#     107     enable_linear_pose6d_solver:={enable_linear_pose6d_solver} debug_rot_init_only:=false"
#     108 s = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
# --> 109 output = s.stdout.read().decode("utf-8")
#     110 err = s.stderr.read()
#     111 pg = PoseGraph()
#
# KeyboardInterrupt:
