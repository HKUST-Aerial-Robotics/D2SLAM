# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
from local_plot import *
from utils import *

# %%
nodes = [1, 2]
output_folder = "//home/xuhao/Dropbox/data/d2slam/two_drone_realworld_2023_1_14/swarm_log_drone1_2/swarm_log_latest/"
dte = 170
paths_vo, t0 = read_paths(output_folder, nodes, t0=None, prefix="d2vins_", dte=dte)
paths_pgo, _ = read_paths(output_folder, nodes, t0=t0, prefix="pgo_", dte=dte)
paths_gt, _ = read_paths(output_folder, nodes, t0=t0, prefix="groundtruth_SwarmNode", dte=dte, reset_orientation=False)
align_paths(paths_vo, paths_gt, align_with_minize=False, align_coor_only=False, align_by_first=True)
align_paths(paths_pgo, paths_gt, align_with_minize=False, align_coor_only=False, align_by_first=True)
display(plot_fused_err(nodes, paths_vo, paths_gt, dte=dte, show=False))
display(plot_relative_pose_err(1, nodes[1:], paths_vo, paths_gt, dte=dte, show=False))
plot_fused(nodes, paths_vo, poses_pgo=paths_pgo, poses_gt=paths_gt, figsize=(10,10), output_path=output_folder)
# Out:
# '<table>\n<tbody>\n<tr><td>Drone</td><td>Traj. Len.</td><td>ATE Pos</td><td>ATE Att</td><td>Cov/m: x</td><td>y      </td><td>z      </td><td>Cov Att/m</td></tr>\n<tr><td>1by1 </td><td>42.3m     </td><td>0.268  </td><td>2.952  </td><td>6.6e-03 </td><td>4.5e-03</td><td>2.1e-03</td><td>8.03e-03 </td></tr>\n<tr><td>2by1 </td><td>39.5m     </td><td>0.261  </td><td>4.429  </td><td>1.5e-02 </td><td>1.9e-02</td><td>1.3e-02</td><td>3.58e-02 </td></tr>\n<tr><td>Avg. </td><td>40.9      </td><td>0.264  </td><td>3.69   </td><td>        </td><td>       </td><td>       </td><td>         </td></tr>\n</tbody>\n</table>'
# '<table>\n<tbody>\n<tr><td>Relative</td><td>EST RMSE: Pos (XYZ)</td><td>POS  </td><td>Ang  </td><td>BIAS: Pos          </td><td>Ang   </td></tr>\n<tr><td>1-&gt;2    </td><td>0.121,0.139,0.141  </td><td>0.232</td><td>4.27°</td><td>0.066,-0.055,-0.015</td><td>-3.91°</td></tr>\n<tr><td>Avg:    </td><td>                   </td><td>0.232</td><td>4.27°</td><td>                   </td><td>      </td></tr>\n</tbody>\n</table>'

# %%
nodes = [1, 2]
output_folder = "//home/xuhao/Dropbox/data/d2slam/two_drone_realworld_2023_1_14/swarm_log_drone1_3/swarm_log_latest/"
dte = 230
paths_vo, t0 = read_paths(output_folder, nodes, t0=None, prefix="d2vins_", dte=dte)
paths_pgo, _ = read_paths(output_folder, nodes, t0=t0, prefix="pgo_", dte=dte)
paths_gt, _ = read_paths(output_folder, nodes, t0=t0, prefix="groundtruth_SwarmNode", dte=dte, reset_orientation=False)
align_paths(paths_vo, paths_gt, align_with_minize=True, align_coor_only=False, align_by_first=True)
align_paths(paths_pgo, paths_gt, align_with_minize=True, align_coor_only=False, align_by_first=True)
display(plot_fused_err(nodes, paths_vo, paths_gt, poses_pgo=paths_pgo, dte=dte, show=False))
display(plot_relative_pose_err(1, nodes[1:], paths_vo, paths_gt, dte=dte, show=False))
plot_fused(nodes, paths_vo, poses_pgo=paths_pgo, poses_gt=paths_gt, figsize=(10,10), output_path=output_folder)
# Out:
# '<table>\n<tbody>\n<tr><td>Drone</td><td>Traj. Len.</td><td>ATE Pos</td><td>ATE Att</td><td>Cov/m: x</td><td>y      </td><td>z      </td><td>Cov Att/m</td><td>PGO:ATE Pos</td><td>ATE Att</td></tr>\n<tr><td>1by1 </td><td>73.2m     </td><td>0.190  </td><td>2.657  </td><td>4.7e-03 </td><td>6.0e-03</td><td>9.0e-04</td><td>7.27e-03 </td><td>0.148      </td><td>2.640° </td></tr>\n<tr><td>2by1 </td><td>73.5m     </td><td>0.249  </td><td>8.718  </td><td>2.6e-03 </td><td>7.2e-03</td><td>1.3e-03</td><td>3.75e-03 </td><td>0.146      </td><td>5.690° </td></tr>\n<tr><td>Avg. </td><td>73.3      </td><td>0.219  </td><td>5.69   </td><td>        </td><td>       </td><td>       </td><td>         </td><td>0.147      </td><td>4.17   </td></tr>\n</tbody>\n</table>'
# '<table>\n<tbody>\n<tr><td>Relative</td><td>EST RMSE: Pos (XYZ)</td><td>POS  </td><td>Ang  </td><td>BIAS: Pos           </td><td>Ang   </td></tr>\n<tr><td>1-&gt;2    </td><td>0.124,0.144,0.100  </td><td>0.214</td><td>8.88°</td><td>-0.005,-0.026,-0.062</td><td>-8.53°</td></tr>\n<tr><td>Avg:    </td><td>                   </td><td>0.214</td><td>8.88°</td><td>                    </td><td>      </td></tr>\n</tbody>\n</table>'

# %%
nodes = [1, 2]
output_folder = "//home/xuhao/Dropbox/data/d2slam/two_drone_realworld_2023_1_14/swarm_log_drone1_4/swarm_log_latest/"
dte = 165
paths_vo, t0 = read_paths(output_folder, nodes, t0=None, prefix="d2vins_", dte=dte)
paths_pgo, _ = read_paths(output_folder, nodes, t0=t0, prefix="pgo_", dte=dte)
paths_gt, _ = read_paths(output_folder, nodes, t0=t0, prefix="groundtruth_SwarmNode", dte=dte, reset_orientation=False)
align_paths(paths_vo, paths_gt, align_with_minize=True, align_coor_only=False, align_by_first=True)
align_paths(paths_pgo, paths_gt, align_with_minize=True, align_coor_only=False, align_by_first=True)
display(plot_fused_err(nodes, paths_vo, paths_gt, poses_pgo=paths_pgo, dte=dte, show=False))
display(plot_relative_pose_err(1, nodes[1:], paths_vo, paths_gt, dte=dte, show=False))
plot_fused(nodes, paths_vo, poses_gt=paths_gt, figsize=(10,10), output_path=output_folder)
# Out:
# '<table>\n<tbody>\n<tr><td>Drone</td><td>Traj. Len.</td><td>ATE Pos</td><td>ATE Att</td><td>Cov/m: x</td><td>y      </td><td>z      </td><td>Cov Att/m</td><td>PGO:ATE Pos</td><td>ATE Att</td></tr>\n<tr><td>1by1 </td><td>51.2m     </td><td>0.113  </td><td>2.243  </td><td>8.7e-04 </td><td>4.0e-03</td><td>3.7e-04</td><td>6.98e-03 </td><td>0.087      </td><td>1.945° </td></tr>\n<tr><td>2by1 </td><td>50.8m     </td><td>0.094  </td><td>3.024  </td><td>1.0e-03 </td><td>5.2e-03</td><td>7.6e-04</td><td>4.57e-02 </td><td>0.093      </td><td>4.246° </td></tr>\n<tr><td>Avg. </td><td>51.0      </td><td>0.103  </td><td>2.63   </td><td>        </td><td>       </td><td>       </td><td>         </td><td>0.090      </td><td>3.10   </td></tr>\n</tbody>\n</table>'
# '<table>\n<tbody>\n<tr><td>Relative</td><td>EST RMSE: Pos (XYZ)</td><td>POS  </td><td>Ang  </td><td>BIAS: Pos          </td><td>Ang   </td></tr>\n<tr><td>1-&gt;2    </td><td>0.047,0.067,0.056  </td><td>0.099</td><td>3.35°</td><td>0.013,-0.027,-0.041</td><td>-3.06°</td></tr>\n<tr><td>Avg:    </td><td>                   </td><td>0.099</td><td>3.35°</td><td>                   </td><td>      </td></tr>\n</tbody>\n</table>'

# %%
nodes = [1, 2]
output_folder = "//home/xuhao/Dropbox/data/d2slam/two_drone_realworld_2023_1_14/swarm_log_drone1_5/swarm_log_latest/"
dte = 170
paths_vo, t0 = read_paths(output_folder, nodes, t0=None, prefix="d2vins_", dte=dte)
paths_pgo, _ = read_paths(output_folder, nodes, t0=t0, prefix="pgo_", dte=dte)
paths_gt, _ = read_paths(output_folder, nodes, t0=t0, prefix="groundtruth_SwarmNode", dte=dte, reset_orientation=False)
align_paths(paths_vo, paths_gt, align_with_minize=False, align_coor_only=False, align_by_first=True)
align_paths(paths_pgo, paths_gt, align_with_minize=False, align_coor_only=False, align_by_first=True)
display(plot_fused_err(nodes, paths_vo, paths_gt, poses_pgo=paths_pgo, dte=dte, show=False))
display(plot_relative_pose_err(1, nodes[1:], paths_vo, paths_gt, dte=dte, show=False))
plot_fused(nodes, paths_vo, poses_pgo=paths_pgo, poses_gt=paths_gt, figsize=(10,10), output_path=output_folder)
# Out:
# '<table>\n<tbody>\n<tr><td>Drone</td><td>Traj. Len.</td><td>ATE Pos</td><td>ATE Att</td><td>Cov/m: x</td><td>y      </td><td>z      </td><td>Cov Att/m</td><td>PGO:ATE Pos</td><td>ATE Att</td></tr>\n<tr><td>1by1 </td><td>41.5m     </td><td>0.232  </td><td>2.612  </td><td>2.6e-03 </td><td>1.4e-03</td><td>7.6e-04</td><td>6.50e-03 </td><td>0.154      </td><td>3.293° </td></tr>\n<tr><td>2by1 </td><td>41.4m     </td><td>0.214  </td><td>4.231  </td><td>2.6e-03 </td><td>1.9e-02</td><td>2.2e-03</td><td>1.46e-02 </td><td>0.264      </td><td>7.735° </td></tr>\n<tr><td>Avg. </td><td>41.4      </td><td>0.223  </td><td>3.42   </td><td>        </td><td>       </td><td>       </td><td>0.2      </td><td>5.51       </td><td>       </td></tr>\n</tbody>\n</table>'
# '<table>\n<tbody>\n<tr><td>Relative</td><td>EST RMSE: Pos (XYZ)</td><td>POS  </td><td>Ang  </td><td>BIAS: Pos           </td><td>Ang   </td></tr>\n<tr><td>1-&gt;2    </td><td>0.184,0.150,0.133  </td><td>0.272</td><td>4.12°</td><td>-0.003,-0.024,-0.093</td><td>-4.01°</td></tr>\n<tr><td>Avg:    </td><td>                   </td><td>0.272</td><td>4.12°</td><td>                    </td><td>      </td></tr>\n</tbody>\n</table>'
