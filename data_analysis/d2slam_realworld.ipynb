# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
from local_plot import *
from utils import *

# %%
nodes = [1, 2]
output_folder = "/home/xuhao/Dropbox/data/d2slam/flight_2/fly2-2023-1-13-2/"
dte = 200
paths_vo, t0 = read_paths(output_folder, nodes, t0=None, prefix="d2vins_", dte=dte)
paths_pgo, _ = read_paths(output_folder, nodes, t0=t0, prefix="pgo_", dte=dte)
paths_gt, _ = read_paths(output_folder, nodes, t0=t0, prefix="groundtruth_SwarmNode", dte=dte, reset_orientation=True)
align_paths(paths_vo, paths_gt)
align_paths(paths_vo, paths_gt)
# display(plot_fused_err(nodes, paths_vo, paths_gt, dte=dte, show=False))
# display(plot_relative_pose_err(1, nodes[1:], paths, paths_gt, dte=dte, show=False))
plot_fused(nodes, paths_vo, poses_pgo=paths_pgo, figsize=(10,10), output_path=output_folder)
# Out:
# dpos by 1 : [-1.21565004  1.89989187  0.05242145]
# dpos by 2 : [-1.320994  3.567062  2.38405 ]
