# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
from local_plot import *
from utils import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
nodes = [1]
output_folder = "/home/xuhao/Dropbox/data/d2slam/flight_2/fly2-2023-1-13-2/"
dte = 75
paths_vo, t0 = read_paths(output_folder, nodes, t0=None, prefix="d2vins_", dte=dte)
paths_pgo, _ = read_paths(output_folder, nodes, t0=t0, prefix="pgo_", dte=dte)
paths_gt, _ = read_paths(output_folder, nodes, t0=t0, prefix="groundtruth_SwarmNode", dte=dte, reset_orientation=False)
# align_paths(paths_vo, paths_gt, align_with_minize=True, align_coor_only=True)
# align_paths(paths_pgo, paths_gt, align_with_minize=True, align_coor_only=True)
display(plot_fused_err(nodes, paths_vo, paths_gt, dte=dte, show=True))
# display(plot_relative_pose_err(1, nodes[1:], paths, paths_gt, dte=dte, show=False))
plot_fused(nodes, paths_vo, poses_pgo=paths_pgo, poses_gt=paths_gt, figsize=(10,10), output_path=output_folder)
# Out:
# '<table>\n<tbody>\n<tr><td>Drone</td><td>Traj. Len.</td><td>ATE Pos</td><td>ATE Att</td><td>Cov/m: x</td><td>y      </td><td>z      </td><td>Cov Att/m</td></tr>\n<tr><td>1by1 </td><td>13.8m     </td><td>1.870  </td><td>136.113</td><td>4.1e-03 </td><td>4.3e-02</td><td>2.5e-02</td><td>1.79e-01 </td></tr>\n<tr><td>Avg. </td><td>13.8      </td><td>1.870  </td><td>136.11 </td><td>        </td><td>       </td><td>       </td><td>         </td></tr>\n</tbody>\n</table>'

# %%
paths_gt
# Out:
# {}

# %%
paths_gt[1]

# %%
paths_pgo
# Out:
# {}
