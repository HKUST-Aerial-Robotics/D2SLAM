# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
from local_plot import *
from utils import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
nodes = [1]
# output_folder = "/home/dji/data/fly_eight_traj_2_2023_1_11"
output_folder = "/home/dji/swarm_log_latest/"
dte = None
paths_vo, t0 = read_paths(output_folder, nodes, t0=None, prefix="d2vins", dte=dte)
paths_pgo, _ = read_paths(output_folder, nodes, t0=t0, prefix="pgo", dte=dte)
plot_fused(nodes, paths_vo, poses_pgo=paths_pgo, figsize=(10,10), output_path=output_folder)

# %%
paths_pgo
# Out:
# {}
